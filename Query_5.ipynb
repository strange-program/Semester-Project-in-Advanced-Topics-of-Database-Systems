# %% [markdown]
# # First Configuration

# %%
# %%configure -f
# {
#     "conf":{
#         "spark.executor.instances": "2",
#         "spark.executor.memory": "8g",
#         "spark.executor.cores": "4"
#     }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1790</td><td>application_1765289937462_1774</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1774/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-213.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1774_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.executor.instances': '2', 'spark.executor.memory': '8g', 'spark.executor.cores': '4'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1773</td><td>application_1765289937462_1757</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1757/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1757_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1777</td><td>application_1765289937462_1761</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1761/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-251.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1761_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1780</td><td>application_1765289937462_1764</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1764/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1764_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1781</td><td>application_1765289937462_1765</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1765/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1765_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1784</td><td>application_1765289937462_1768</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1768/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-103.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1768_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1789</td><td>application_1765289937462_1773</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1773/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-48.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1773_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1790</td><td>application_1765289937462_1774</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1774/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-213.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1774_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
from sedona.spark import *

# Create sedona context
sedona = SedonaContext.create(spark)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, DoubleType, StringType
from pyspark.sql.functions import udf

from pyspark.sql.functions import col, sum, round, count
from pyspark.sql import functions as F
import time

income_schema =  StructType([
    StructField("Zip_code", IntegerType()),
    StructField("Community", StringType()),
    StructField("Est_med_income", StringType())
])

crime_schema = StructType([
    StructField("DR_NO", IntegerType()),
    StructField("Date Rptd", StringType()),
    StructField("DATE OCC", StringType()),
    StructField("TIME OCC", IntegerType()),
    StructField("AREA", IntegerType()),
    StructField("AREA NAME", StringType()),
    StructField("Rpt Dist No", IntegerType()),
    StructField("Part 1-2", IntegerType()),
    StructField("Crm Cd", IntegerType()),
    StructField("Crm Cd Desc", StringType()),
    StructField("Mocodes", StringType()),
    StructField("Vict Age", IntegerType()),
    StructField("Vict Sex", StringType()),
    StructField("Vict Descent", StringType()),
    StructField("Premis Cd", IntegerType()),
    StructField("Premis Desc", StringType()),
    StructField("Weapon Used Cd", IntegerType()),
    StructField("Weapon Desc", StringType()),
    StructField("Status", StringType()),
    StructField("Status Descent", StringType()),
    StructField("Crm Cd 1", IntegerType()),
    StructField("Crm Cd 2", IntegerType()),
    StructField("Crm Cd 3", IntegerType()),
    StructField("Crm Cd 4", IntegerType()),
    StructField("LOCATION", StringType()),
    StructField("Cross Street", StringType()),
    StructField("LAT", DoubleType()),
    StructField("LON", DoubleType()),
])

# Convert dollar value to float
def money_to_int(x):
    if (x=="---"): return 0
    vals = x.split('$')[1].split(',')
    vals[1] = vals[1].split(' ')[0]
    res = ''.join(vals)
    return int(res)

money_to_int_udf = udf(money_to_int)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
start = time.time()

# Read census data for 2020
# Read the file from s3
geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson"
blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(geojson_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")

# Formatting magic
flattened_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type")

# Read income for 2021
income_df = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_income_2021.csv",
    header=True,
    schema=income_schema,
    sep=";"
)

# Convert dollar values to integers
income_df = income_df.withColumn("median_income", money_to_int_udf(col("Est_med_income"))).drop("Est_med_income")

# Read crime data for period 2020-
crime_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
    header=True, \
    schema=crime_schema)

# Exclude data that don't belong to years 2020 and 2021
# Also exclude data in the null island
crime_df.withColumn("year",F.year(F.to_timestamp(col("DATE OCC"), "yyyy MMM dd hh:mm:ss a")))\
    .filter((col("year")==2020) | (col("year")==2021))\
    .drop("year")\
    .filter((col("LON")==0) & (col("LAT")==0))

# Data loading and preprocessing is over
# Perform main computatiom
# Join census blocks with income per zip code
census_income = flattened_df.join(income_df, flattened_df.ZCTA20==income_df.Zip_code)\
    .select("COMM","HOUSING20","POP20","median_income")\
    .withColumn("total_income", col("median_income")*col("HOUSING20"))\
    .filter(col("POP20")!=0)\
    .drop("HOUSING20", "median_income")

# Calculate income per capita per area
income_per_area = census_income.groupBy("COMM")\
    .agg(round(sum("total_income")/sum("POP20"),2).alias("Per Capita Income"))\
    .na.replace("", "Los Angeles County", subset=["COMM"])\
    .withColumnRenamed("COMM", "COMM_name")

# Aggregate areas over the geometry value
LA_areas = flattened_df.filter(col("CITY") == "Los Angeles") \
                .groupBy("COMM") \
                .agg(ST_Union_Aggr("geometry").alias("geometry"),sum("POP20").alias("Population"))

# Find the area for each crime
join_crime_area = crime_df.join(LA_areas, ST_Within(ST_Point(crime_df.LON, crime_df.LAT), LA_areas.geometry), "inner")\
    .select("COMM","DR_NO","Population")

# Aggregate crimes over areas to get average crime per person and area
crimes_per_person_x_area = join_crime_area.groupBy("COMM")\
    .agg((1000*count("DR_NO")/sum("Population")).alias("Crimes per area per 1K people"))\
    .na.replace("", "Los Angeles County", subset=["COMM"])

# Combine average crimes per person with income per person for each area
result = crimes_per_person_x_area.join(income_per_area, crimes_per_person_x_area.COMM==income_per_area.COMM_name).drop("COMM_name")
result.show(1000,truncate=False)

results_top10 = result.orderBy("Per Capita Income",ascending=False)
results_bottom10 = result.orderBy("Per Capita Income",ascending=True)
results_top10.show(10)
results_bottom10.show(10)

end = time.time()
print("Elapsed time: ",end-start)
result.explain(mode="formatted")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------------+-----------------------------+-----------------+
# |COMM                   |Crimes per area per 1K people|Per Capita Income|
# +-----------------------+-----------------------------+-----------------+
# |Toluca Terrace         |0.7363770250368189           |25786.81         |
# |Elysian Park           |0.21235931195582927          |26141.35         |
# |Longwood               |0.26062027625749284          |20725.21         |
# |Green Meadows          |0.04729921483303377          |11848.86         |
# |Cadillac-Corning       |0.1643115346697338           |33043.29         |
# |Lincoln Heights        |0.03406690740614567          |18288.88         |
# |Van Nuys               |0.01106941630967799          |20630.62         |
# |Gramercy Place         |0.09433072351664937          |23247.01         |
# |Faircrest Heights      |0.2745744096650192           |31042.24         |
# |Boyle Heights          |0.01272070421818552          |14566.39         |
# |Lafayette Square       |0.2425418384671356           |23451.22         |
# |Granada Hills          |0.0175530981218185           |35259.1          |
# |North Hills            |0.017220892386643476         |21064.88         |
# |Northridge             |0.014647722279185586         |29478.63         |
# |Wilshire Center        |0.02122826756108434          |24451.91         |
# |Jefferson Park         |0.1362583458236817           |17661.79         |
# |Vermont Square         |0.13192612137203166          |13262.2          |
# |Cloverdale/Cochran     |0.07526153383005946          |21294.0          |
# |Adams-Normandie        |0.13175230566534915          |14800.07         |
# |Harbor Pines           |0.38895371450797356          |26844.5          |
# |Encino                 |0.0222000222000222           |46201.43         |
# |Reynier Village        |0.2484472049689441           |37616.49         |
# |Toluca Woods           |0.5685048322910745           |32699.97         |
# |Glassell Park          |0.03552902721523485          |30934.01         |
# |Silverlake             |0.024313744559799656         |37910.91         |
# |Sunland                |0.04815100154083205          |35422.28         |
# |Cheviot Hills          |0.10429703796412182          |43166.79         |
# |Carthay                |0.07102272727272728          |62780.31         |
# |West Los Angeles       |0.02658796628645875          |55240.44         |
# |South Carthay          |0.0963855421686747           |51376.68         |
# |Country Club Park      |0.07134703196347032          |22371.86         |
# |Venice                 |0.0299007295778017           |63437.58         |
# |University Hills       |0.30165912518853694          |16425.37         |
# |Century Palms/Cove     |0.03060818462856968          |12635.49         |
# |Playa Vista            |0.061614294516327786         |81679.88         |
# |Chinatown              |0.11486331265793706          |27042.9          |
# |Beverlywood            |0.07707129094412331          |40121.15         |
# |Manchester Square      |0.11892020454275182          |23070.34         |
# |Temple-Beaudry         |0.02880350250590472          |24479.5          |
# |Figueroa Park Square   |0.11684973124561814          |13515.15         |
# |Beverly Crest          |0.08390669575432119          |69669.54         |
# |Koreatown              |0.02114299004165169          |21215.23         |
# |Harbor City            |0.03501277966457757          |26864.39         |
# |Pacific Palisades      |0.047728140511645666         |87750.53         |
# |Angelino Heights       |0.41135335252982314          |31017.08         |
# |North Hollywood        |0.007040319912136808         |24426.48         |
# |Atwater Village        |0.06927606511950121          |41900.44         |
# |Canoga Park            |0.0159675539304134           |25912.14         |
# |Harvard Heights        |0.06326711375427053          |16551.19         |
# |Reseda                 |0.013432194283258113         |22391.61         |
# |Playa Del Rey          |0.3380662609871535           |60390.17         |
# |Brentwood              |0.0329663084327817           |72946.35         |
# |Alsace                 |0.0947597839476926           |17898.2          |
# |South Park             |0.027771606309708954         |11413.4          |
# |Studio City            |0.04457321149988857          |56739.51         |
# |Mandeville Canyon      |0.30845157310302285          |65870.07         |
# |Crestview              |0.08841732979664015          |45113.51         |
# |Panorama City          |0.014337534230862977         |14545.04         |
# |Hollywood Hills        |0.03369385760975774          |51789.48         |
# |Exposition             |0.3155569580309246           |17846.82         |
# |Exposition Park        |0.023575453238088503         |15577.68         |
# |Angeles National Forest|90.9090909090909             |33611.5          |
# |Regent Square          |0.40064102564102566          |33396.47         |
# |Lake Balboa            |0.02530684550170821          |22825.54         |
# |Central                |0.028786919223904656         |11541.45         |
# |Westchester            |0.019700551615445233         |52322.51         |
# |Winnetka               |0.020229401412012217         |24471.42         |
# |Wellington Square      |0.21486892995272883          |20548.99         |
# |Reseda Ranch           |0.228310502283105            |19728.41         |
# |Little Bangladesh      |0.03660456092829167          |25614.96         |
# |West Vernon            |0.019612073192257152         |14563.15         |
# |Vernon Central         |0.020505669817704596         |10950.15         |
# |Mt. Washington         |0.04689551678859501          |27936.81         |
# |Bel Air                |0.12906556530717606          |80412.74         |
# |Victoria Park          |0.13568521031207598          |22641.39         |
# |Mar Vista              |0.025267839094400647         |44320.68         |
# |Park La Brea           |0.0813868316106454           |45839.82         |
# |Del Rey                |0.03417518198284406          |49760.66         |
# |Baldwin Hills          |0.03322700691121744          |23104.69         |
# |Elysian Valley         |0.11291779584462511          |26598.33         |
# |Vermont Knolls         |0.05667327854916407          |15385.27         |
# |Century City           |0.07352941176470588          |58903.82         |
# |Wholesale District     |0.025019390027271136         |13402.1          |
# |Palisades Highlands    |0.25568908207619534          |83576.89         |
# |Valley Village         |0.04020747054802783          |39062.27         |
# |Mission Hills          |0.0428577551107873           |23458.86         |
# |Thai Town              |0.1144950767117014           |44489.05         |
# |El Sereno              |0.026218505020843712         |21067.45         |
# |Vermont Vista          |0.025004375765759007         |12434.68         |
# |Pacoima                |0.013878094815143778         |16897.22         |
# |San Pedro              |0.013277743845765728         |29063.09         |
# |Watts                  |0.023670880083321497         |11751.34         |
# |Harvard Park           |0.026193095500026194         |14605.37         |
# |Hyde Park              |0.03432533553015481          |21915.61         |
# |Arleta                 |0.03178134435086604          |17205.06         |
# |Downtown               |0.024447486798357128         |30629.75         |
# |Mid-City               |0.0687001923605386           |28314.74         |
# |Tujunga                |0.03654703603537753          |28149.1          |
# |Chatsworth             |0.027145881969705195         |37614.65         |
# |St Elmo Village        |0.2531004808909137           |20055.22         |
# |Westwood               |0.017472131949540483         |27713.56         |
# |Little Tokyo           |0.17599436818021824          |17460.53         |
# |University Park        |0.03883042752300703          |12374.62         |
# |Sylmar                 |0.012208521548040533         |22751.64         |
# |Marina Peninsula       |0.20395676116663267          |85588.53         |
# |Miracle Mile           |0.05788712011577424          |49244.19         |
# |West Hills             |0.025597706445502483         |35703.27         |
# |Hollywood              |0.015274404680077593         |38420.29         |
# |Hancock Park           |0.06119202056051891          |30052.02         |
# |Shadow Hills           |0.21510002151000215          |33238.6          |
# |Eagle Rock             |0.02755655983906969          |33382.71         |
# |Pico-Union             |0.025625256252562525         |16225.59         |
# |Historic Filipinotown  |0.08335417187630241          |26243.66         |
# |Brookside              |1.3888888888888888           |20404.61         |
# |Little Armenia         |0.14405070584845867          |25330.42         |
# |Rancho Park            |0.15008254539996999          |55901.24         |
# |Tarzana                |0.032255983484936454         |37247.29         |
# |Sycamore Square        |1.4903129657228018           |37200.69         |
# |Echo Park              |0.07535227187099691          |34006.69         |
# |Harbor Gateway         |0.024335044898157836         |23088.7          |
# |Wilmington             |0.019420869666543668         |15343.78         |
# |Porter Ranch           |0.02799787216171571          |45063.49         |
# |Palms                  |0.023715227547608318         |45580.7          |
# |Sun Valley             |0.019644821625019643         |18595.88         |
# |Leimert Park           |0.06318316800404372          |22043.61         |
# |Melrose                |0.014059160949274547         |31333.25         |
# |Westlake               |0.017721698447579214         |18405.87         |
# |Florence-Firestone     |0.021843122692820165         |12294.28         |
# |East Hollywood         |0.040859687831984966         |23993.82         |
# |Highland Park          |0.023205625043510546         |31770.2          |
# |Sherman Oaks           |0.011385760967334253         |47035.57         |
# |Valley Glen            |0.03514444366345681          |24204.1          |
# |Woodland Hills         |0.014030361702724696         |45357.01         |
# |Toluca Lake            |0.11301989150090416          |44527.72         |
# |View Heights           |0.28901734104046245          |24421.56         |
# |Lakeview Terrace       |0.07815552950371239          |24082.97         |
# |West Adams             |0.03794778384942319          |18245.62         |
# |Los Feliz              |0.047523999619808            |44162.66         |
# |Crenshaw District      |0.07452120128176466          |22055.08         |
# +-----------------------+-----------------------------+-----------------+
#
# +-------------------+-----------------------------+-----------------+
# |               COMM|Crimes per area per 1K people|Per Capita Income|
# +-------------------+-----------------------------+-----------------+
# |  Pacific Palisades|         0.047728140511645666|         87750.53|
# |   Marina Peninsula|          0.20395676116663267|         85588.53|
# |Palisades Highlands|          0.25568908207619534|         83576.89|
# |        Playa Vista|         0.061614294516327786|         81679.88|
# |            Bel Air|          0.12906556530717606|         80412.74|
# |          Brentwood|           0.0329663084327817|         72946.35|
# |      Beverly Crest|          0.08390669575432119|         69669.54|
# |  Mandeville Canyon|          0.30845157310302285|         65870.07|
# |             Venice|           0.0299007295778017|         63437.58|
# |            Carthay|          0.07102272727272728|         62780.31|
# +-------------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# +------------------+-----------------------------+-----------------+
# |              COMM|Crimes per area per 1K people|Per Capita Income|
# +------------------+-----------------------------+-----------------+
# |    Vernon Central|         0.020505669817704596|         10950.15|
# |        South Park|         0.027771606309708954|          11413.4|
# |           Central|         0.028786919223904656|         11541.45|
# |             Watts|         0.023670880083321497|         11751.34|
# |     Green Meadows|          0.04729921483303377|         11848.86|
# |Florence-Firestone|         0.021843122692820165|         12294.28|
# |   University Park|          0.03883042752300703|         12374.62|
# |     Vermont Vista|         0.025004375765759007|         12434.68|
# |Century Palms/Cove|          0.03060818462856968|         12635.49|
# |    Vermont Square|          0.13192612137203166|          13262.2|
# +------------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# Elapsed time:  82.18367433547974
# == Physical Plan ==
# AdaptiveSparkPlan (37)
# +- Project (36)
#    +- SortMergeJoin Inner (35)
#       :- Sort (17)
#       :  +- Exchange (16)
#       :     +- HashAggregate (15)
#       :        +- Exchange (14)
#       :           +- HashAggregate (13)
#       :              +- Project (12)
#       :                 +- RangeJoin (11)
#       :                    :- Scan csv  (1)
#       :                    +- Filter (10)
#       :                       +- ObjectHashAggregate (9)
#       :                          +- Exchange (8)
#       :                             +- ObjectHashAggregate (7)
#       :                                +- Project (6)
#       :                                   +- Filter (5)
#       :                                      +- Generate (4)
#       :                                         +- Filter (3)
#       :                                            +- Scan geojson  (2)
#       +- Sort (34)
#          +- Exchange (33)
#             +- HashAggregate (32)
#                +- Exchange (31)
#                   +- HashAggregate (30)
#                      +- Project (29)
#                         +- BroadcastHashJoin Inner BuildRight (28)
#                            :- Project (22)
#                            :  +- Filter (21)
#                            :     +- Generate (20)
#                            :        +- Filter (19)
#                            :           +- Scan geojson  (18)
#                            +- BroadcastExchange (27)
#                               +- Project (26)
#                                  +- BatchEvalPython (25)
#                                     +- Filter (24)
#                                        +- Scan csv  (23)
#
#
# (1) Scan csv
# Output [3]: [DR_NO#206, LAT#232, LON#233]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv]
# ReadSchema: struct<DR_NO:int,LAT:double,LON:double>
#
# (2) Scan geojson
# Output [1]: [features#25]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string,BGFIP20:string,CB20:string,CITY:string,CITYCOMM:string,CITYCOMM_CURRENT:string,CITY_CURRENT:string,COMM:string,COMM_CURRENT:string,COUNTY:string,CT20:string,CTCB20:string,FEAT_TYPE:string,FIP20:string,FIP_CURRENT:string,HD22:bigint,HD_NAME:string,HOUSING20:bigint,OBJECTID:bigint,POP20:bigint,SPA22:bigint,SPA_NAME:string,SUP21:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,State:string,ZCTA20:string>,type:string>>>
#
# (3) Filter
# Input [1]: [features#25]
# Condition : ((size(features#25, true) > 0) AND isnotnull(features#25))
#
# (4) Generate
# Input [1]: [features#25]
# Arguments: explode(features#25), false, [features#33]
#
# (5) Filter
# Input [1]: [features#33]
# Condition : ((isnotnull(features#33.properties.CITY) AND (features#33.properties.CITY = Los Angeles)) AND CASE WHEN (features#33.properties.COMM = ) THEN true ELSE isnotnull(features#33.properties.COMM) END)
#
# (6) Project
# Output [3]: [features#33.properties.COMM AS COMM#50, features#33.properties.POP20 AS POP20#62L, features#33.geometry AS geometry#36]
# Input [1]: [features#33]
#
# (7) ObjectHashAggregate
# Input [3]: [COMM#50, POP20#62L, geometry#36]
# Keys [1]: [COMM#50]
# Functions [2]: [partial_st_union_aggr(geometry#36, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@3d93861f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None), partial_sum(POP20#62L)]
# Aggregate Attributes [2]: [buf#576, sum#578L]
# Results [3]: [COMM#50, buf#577, sum#579L]
#
# (8) Exchange
# Input [3]: [COMM#50, buf#577, sum#579L]
# Arguments: hashpartitioning(COMM#50, 1000), ENSURE_REQUIREMENTS, [plan_id=2254]
#
# (9) ObjectHashAggregate
# Input [3]: [COMM#50, buf#577, sum#579L]
# Keys [1]: [COMM#50]
# Functions [2]: [st_union_aggr(geometry#36, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@3d93861f, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None), sum(POP20#62L)]
# Aggregate Attributes [2]: [ST_Union_Aggr(geometry#36)#449, sum(POP20#62L)#451L]
# Results [3]: [COMM#50, ST_Union_Aggr(geometry#36)#449 AS geometry#450, sum(POP20#62L)#451L AS Population#452L]
#
# (10) Filter
# Input [3]: [COMM#50, geometry#450, Population#452L]
# Condition : isnotnull(geometry#450)
#
# (11) RangeJoin
# Arguments:  **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  , geometry#450: geometry, WITHIN
#
# (12) Project
# Output [3]: [COMM#50, DR_NO#206, Population#452L]
# Input [6]: [DR_NO#206, LAT#232, LON#233, COMM#50, geometry#450, Population#452L]
#
# (13) HashAggregate
# Input [3]: [COMM#50, DR_NO#206, Population#452L]
# Keys [1]: [COMM#50]
# Functions [2]: [partial_count(DR_NO#206), partial_sum(Population#452L)]
# Aggregate Attributes [2]: [count#572L, sum#574L]
# Results [3]: [COMM#50, count#573L, sum#575L]
#
# (14) Exchange
# Input [3]: [COMM#50, count#573L, sum#575L]
# Arguments: hashpartitioning(COMM#50, 1000), ENSURE_REQUIREMENTS, [plan_id=2261]
#
# (15) HashAggregate
# Input [3]: [COMM#50, count#573L, sum#575L]
# Keys [1]: [COMM#50]
# Functions [2]: [count(DR_NO#206), sum(Population#452L)]
# Aggregate Attributes [2]: [count(DR_NO#206)#536L, sum(Population#452L)#537L]
# Results [2]: [CASE WHEN (COMM#50 = ) THEN Los Angeles County ELSE COMM#50 END AS COMM#543, (cast((count(DR_NO#206)#536L * 1000) as double) / cast(sum(Population#452L)#537L as double)) AS Crimes per area per 1K people#538]
#
# (16) Exchange
# Input [2]: [COMM#543, Crimes per area per 1K people#538]
# Arguments: hashpartitioning(COMM#543, 1000), ENSURE_REQUIREMENTS, [plan_id=2272]
#
# (17) Sort
# Input [2]: [COMM#543, Crimes per area per 1K people#538]
# Arguments: [COMM#543 ASC NULLS FIRST], false, 0
#
# (18) Scan geojson
# Output [1]: [features#547]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson]
# PushedFilters: [IsNotNull(features)]
# ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string,BGFIP20:string,CB20:string,CITY:string,CITYCOMM:string,CITYCOMM_CURRENT:string,CITY_CURRENT:string,COMM:string,COMM_CURRENT:string,COUNTY:string,CT20:string,CTCB20:string,FEAT_TYPE:string,FIP20:string,FIP_CURRENT:string,HD22:bigint,HD_NAME:string,HOUSING20:bigint,OBJECTID:bigint,POP20:bigint,SPA22:bigint,SPA_NAME:string,SUP21:string,SUP_LABEL:string,ShapeSTArea:double,ShapeSTLength:double,State:string,ZCTA20:string>,type:string>>>
#
# (19) Filter
# Input [1]: [features#547]
# Condition : ((size(features#547, true) > 0) AND isnotnull(features#547))
#
# (20) Generate
# Input [1]: [features#547]
# Arguments: explode(features#547), false, [features#33]
#
# (21) Filter
# Input [1]: [features#33]
# Condition : ((isnotnull(features#33.properties.POP20) AND NOT (features#33.properties.POP20 = 0)) AND (isnotnull(features#33.properties.ZCTA20) AND CASE WHEN (features#33.properties.COMM = ) THEN true ELSE isnotnull(features#33.properties.COMM) END))
#
# (22) Project
# Output [4]: [features#33.properties.COMM AS COMM#50, features#33.properties.HOUSING20 AS HOUSING20#60L, features#33.properties.POP20 AS POP20#62L, features#33.properties.ZCTA20 AS ZCTA20#70]
# Input [1]: [features#33]
#
# (23) Scan csv
# Output [2]: [Zip_code#190, Est_med_income#192]
# Batched: false
# Location: InMemoryFileIndex [s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_income_2021.csv]
# PushedFilters: [IsNotNull(Zip_code)]
# ReadSchema: struct<Zip_code:int,Est_med_income:string>
#
# (24) Filter
# Input [2]: [Zip_code#190, Est_med_income#192]
# Condition : isnotnull(Zip_code#190)
#
# (25) BatchEvalPython
# Input [2]: [Zip_code#190, Est_med_income#192]
# Arguments: [money_to_int(Est_med_income#192)#196], [pythonUDF0#770]
#
# (26) Project
# Output [2]: [Zip_code#190, pythonUDF0#770 AS median_income#197]
# Input [3]: [Zip_code#190, Est_med_income#192, pythonUDF0#770]
#
# (27) BroadcastExchange
# Input [2]: [Zip_code#190, median_income#197]
# Arguments: HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=2263]
#
# (28) BroadcastHashJoin
# Left keys [1]: [cast(ZCTA20#70 as int)]
# Right keys [1]: [Zip_code#190]
# Join type: Inner
# Join condition: None
#
# (29) Project
# Output [3]: [COMM#50, POP20#62L, (cast(median_income#197 as double) * cast(HOUSING20#60L as double)) AS total_income#391]
# Input [6]: [COMM#50, HOUSING20#60L, POP20#62L, ZCTA20#70, Zip_code#190, median_income#197]
#
# (30) HashAggregate
# Input [3]: [COMM#50, POP20#62L, total_income#391]
# Keys [1]: [COMM#50]
# Functions [2]: [partial_sum(total_income#391), partial_sum(POP20#62L)]
# Aggregate Attributes [2]: [sum#580, sum#582L]
# Results [3]: [COMM#50, sum#581, sum#583L]
#
# (31) Exchange
# Input [3]: [COMM#50, sum#581, sum#583L]
# Arguments: hashpartitioning(COMM#50, 1000), ENSURE_REQUIREMENTS, [plan_id=2268]
#
# (32) HashAggregate
# Input [3]: [COMM#50, sum#581, sum#583L]
# Keys [1]: [COMM#50]
# Functions [2]: [sum(total_income#391), sum(POP20#62L)]
# Aggregate Attributes [2]: [sum(total_income#391)#403, sum(POP20#62L)#404L]
# Results [2]: [CASE WHEN (COMM#50 = ) THEN Los Angeles County ELSE COMM#50 END AS COMM_name#413, round((sum(total_income#391)#403 / cast(sum(POP20#62L)#404L as double)), 2) AS Per Capita Income#405]
#
# (33) Exchange
# Input [2]: [COMM_name#413, Per Capita Income#405]
# Arguments: hashpartitioning(COMM_name#413, 1000), ENSURE_REQUIREMENTS, [plan_id=2273]
#
# (34) Sort
# Input [2]: [COMM_name#413, Per Capita Income#405]
# Arguments: [COMM_name#413 ASC NULLS FIRST], false, 0
#
# (35) SortMergeJoin
# Left keys [1]: [COMM#543]
# Right keys [1]: [COMM_name#413]
# Join type: Inner
# Join condition: None
#
# (36) Project
# Output [3]: [COMM#543, Crimes per area per 1K people#538, Per Capita Income#405]
# Input [4]: [COMM#543, Crimes per area per 1K people#538, COMM_name#413, Per Capita Income#405]
#
# (37) AdaptiveSparkPlan
# Output [3]: [COMM#543, Crimes per area per 1K people#538, Per Capita Income#405]
# Arguments: isFinalPlan=false

# %% [markdown]
# # Second configuration

# %% [markdown]
# In the following 2 configurations we just want to measure execution times. Therefore, we don't present the execution plan (since its the same) and only print one row of each relation, since we have already printed the results above

# %%
# %%configure -f
# {
#     "conf":{
#         "spark.executor.instances": "4",
#         "spark.executor.memory": "4g",
#         "spark.executor.cores": "2"
#     }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1785</td><td>application_1765289937462_1769</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1769/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-131.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1769_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.executor.instances': '4', 'spark.executor.memory': '4g', 'spark.executor.cores': '2'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1720</td><td>application_1765289937462_1704</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1704/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1704_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1773</td><td>application_1765289937462_1757</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1757/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1757_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1777</td><td>application_1765289937462_1761</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1761/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-251.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1761_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1780</td><td>application_1765289937462_1764</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1764/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1764_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1781</td><td>application_1765289937462_1765</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1765/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1765_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1784</td><td>application_1765289937462_1768</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1768/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-103.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1768_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1785</td><td>application_1765289937462_1769</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1769/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-131.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1769_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, DoubleType, StringType
from pyspark.sql.functions import udf

from pyspark.sql.functions import col, sum, round, count
from pyspark.sql import functions as F
import time

from sedona.spark import *

# Create sedona context
sedona = SedonaContext.create(spark)

income_schema =  StructType([
    StructField("Zip_code", IntegerType()),
    StructField("Community", StringType()),
    StructField("Est_med_income", StringType())
])

crime_schema = StructType([
    StructField("DR_NO", IntegerType()),
    StructField("Date Rptd", StringType()),
    StructField("DATE OCC", StringType()),
    StructField("TIME OCC", IntegerType()),
    StructField("AREA", IntegerType()),
    StructField("AREA NAME", StringType()),
    StructField("Rpt Dist No", IntegerType()),
    StructField("Part 1-2", IntegerType()),
    StructField("Crm Cd", IntegerType()),
    StructField("Crm Cd Desc", StringType()),
    StructField("Mocodes", StringType()),
    StructField("Vict Age", IntegerType()),
    StructField("Vict Sex", StringType()),
    StructField("Vict Descent", StringType()),
    StructField("Premis Cd", IntegerType()),
    StructField("Premis Desc", StringType()),
    StructField("Weapon Used Cd", IntegerType()),
    StructField("Weapon Desc", StringType()),
    StructField("Status", StringType()),
    StructField("Status Descent", StringType()),
    StructField("Crm Cd 1", IntegerType()),
    StructField("Crm Cd 2", IntegerType()),
    StructField("Crm Cd 3", IntegerType()),
    StructField("Crm Cd 4", IntegerType()),
    StructField("LOCATION", StringType()),
    StructField("Cross Street", StringType()),
    StructField("LAT", DoubleType()),
    StructField("LON", DoubleType()),
])

# Convert dollar value to float
def money_to_int(x):
    if (x=="---"): return 0
    vals = x.split('$')[1].split(',')
    vals[1] = vals[1].split(' ')[0]
    res = ''.join(vals)
    return int(res)

money_to_int_udf = udf(money_to_int)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Create sedona context
sedona = SedonaContext.create(spark)

start = time.time()

# Read census data for 2020
# Read the file from s3
geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson"
blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(geojson_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")

# Formatting magic
flattened_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type")

# Read income for 2021
income_df = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_income_2021.csv",
    header=True,
    schema=income_schema,
    sep=";"
)

# Convert dollar values to integers
income_df = income_df.withColumn("median_income",money_to_int_udf(col("Est_med_income"))).drop("Est_med_income")

# Read crime data for period 2020-
crime_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
    header=True, \
    schema=crime_schema)

# Exclude data that don't belong to years 2020 and 2021
# Also exclude data in the null island
crime_df.withColumn("year",F.year(F.to_timestamp(col("DATE OCC"), "yyyy MMM dd hh:mm:ss a")))\
    .filter((col("year")==2020) | (col("year")==2021))\
    .drop("year")\
    .filter((col("LON")==0) & (col("LAT")==0))

# Data loading and preprocessing is over
# Perform main computatiom
# Join census blocks with income per zip code
census_income = flattened_df.join(income_df, flattened_df.ZCTA20==income_df.Zip_code)\
    .select("COMM","HOUSING20","POP20","median_income")\
    .withColumn("total_income",col("median_income")*col("HOUSING20"))\
    .filter(col("POP20")!=0)\
    .drop("HOUSING20","median_income")

# Calculate income per capita per area
income_per_area = census_income.groupBy("COMM")\
    .agg(round(sum("total_income")/sum("POP20"),2).alias("Per Capita Income"))\
    .na.replace("", "Los Angeles County", subset=["COMM"])\
    .withColumnRenamed("COMM", "COMM_name")

# Aggregate areas over the geometry value
LA_areas = flattened_df.filter(col("CITY") == "Los Angeles") \
                .groupBy("COMM") \
                .agg(ST_Union_Aggr("geometry").alias("geometry"),sum("POP20").alias("Population"))

# Find the area for each crime
join_crime_area = crime_df.join(LA_areas, ST_Within(ST_Point(crime_df.LON, crime_df.LAT), LA_areas.geometry), "inner")\
    .select("COMM","DR_NO","Population")

# Aggregate crimes over areas to get average crime per person and area
crimes_per_person_x_area = join_crime_area.groupBy("COMM")\
    .agg((1000*count("DR_NO")/sum("Population")).alias("Crimes per area per 1K people"))\
    .na.replace("", "Los Angeles County", subset=["COMM"])

# Combine average crimes per person with income per person for each area
result = crimes_per_person_x_area.join(income_per_area, crimes_per_person_x_area.COMM==income_per_area.COMM_name).drop("COMM_name")
result.show(10,truncate=False)

results_top10 = result.orderBy("Per Capita Income",ascending=False)
results_bottom10 = result.orderBy("Per Capita Income",ascending=True)
results_top10.show(10)
results_bottom10.show(10)

end = time.time()
print("Elapsed time: ",end-start)
#result.explain(mode="formatted")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------+-----------------------------+-----------------+
# |COMM             |Crimes per area per 1K people|Per Capita Income|
# +-----------------+-----------------------------+-----------------+
# |Toluca Terrace   |0.7363770250368189           |25786.81         |
# |Elysian Park     |0.21235931195582927          |26141.35         |
# |Longwood         |0.26062027625749284          |20725.21         |
# |Green Meadows    |0.04729921483303377          |11848.86         |
# |Cadillac-Corning |0.1643115346697338           |33043.29         |
# |Lincoln Heights  |0.03406690740614567          |18288.88         |
# |Van Nuys         |0.01106941630967799          |20630.62         |
# |Gramercy Place   |0.09433072351664937          |23247.01         |
# |Faircrest Heights|0.2745744096650192           |31042.24         |
# |Boyle Heights    |0.01272070421818552          |14566.39         |
# +-----------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# +-------------------+-----------------------------+-----------------+
# |               COMM|Crimes per area per 1K people|Per Capita Income|
# +-------------------+-----------------------------+-----------------+
# |  Pacific Palisades|         0.047728140511645666|         87750.53|
# |   Marina Peninsula|          0.20395676116663267|         85588.53|
# |Palisades Highlands|          0.25568908207619534|         83576.89|
# |        Playa Vista|         0.061614294516327786|         81679.88|
# |            Bel Air|          0.12906556530717606|         80412.74|
# |          Brentwood|           0.0329663084327817|         72946.35|
# |      Beverly Crest|          0.08390669575432119|         69669.54|
# |  Mandeville Canyon|          0.30845157310302285|         65870.07|
# |             Venice|           0.0299007295778017|         63437.58|
# |            Carthay|          0.07102272727272728|         62780.31|
# +-------------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# +------------------+-----------------------------+-----------------+
# |              COMM|Crimes per area per 1K people|Per Capita Income|
# +------------------+-----------------------------+-----------------+
# |    Vernon Central|         0.020505669817704596|         10950.15|
# |        South Park|         0.027771606309708954|          11413.4|
# |           Central|         0.028786919223904656|         11541.45|
# |             Watts|         0.023670880083321497|         11751.34|
# |     Green Meadows|          0.04729921483303377|         11848.86|
# |Florence-Firestone|         0.021843122692820165|         12294.28|
# |   University Park|          0.03883042752300703|         12374.62|
# |     Vermont Vista|         0.025004375765759007|         12434.68|
# |Century Palms/Cove|          0.03060818462856968|         12635.49|
# |    Vermont Square|          0.13192612137203166|          13262.2|
# +------------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# Elapsed time:  79.42865085601807

# %% [markdown]
# # Third configuration

# %%
# %%configure -f
# {
#     "conf":{
#         "spark.executor.instances": "8",
#         "spark.executor.memory": "2g",
#         "spark.executor.cores": "1"
#     }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1787</td><td>application_1765289937462_1771</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1771/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-250.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1771_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.executor.instances': '8', 'spark.executor.memory': '2g', 'spark.executor.cores': '1'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1720</td><td>application_1765289937462_1704</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1704/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1704_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1773</td><td>application_1765289937462_1757</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1757/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1757_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1777</td><td>application_1765289937462_1761</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1761/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-251.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1761_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1780</td><td>application_1765289937462_1764</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1764/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1764_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1781</td><td>application_1765289937462_1765</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1765/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-30.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1765_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1784</td><td>application_1765289937462_1768</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1768/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-103.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1768_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1786</td><td>application_1765289937462_1770</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1770/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-48.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1770_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>1787</td><td>application_1765289937462_1771</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_1771/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-250.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_1771_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, DoubleType, StringType
from pyspark.sql.functions import udf

from pyspark.sql.functions import col, sum, round, count
from pyspark.sql import functions as F
import time

from sedona.spark import *

# Create sedona context
sedona = SedonaContext.create(spark)

income_schema =  StructType([
    StructField("Zip_code", IntegerType()),
    StructField("Community", StringType()),
    StructField("Est_med_income", StringType())
])

crime_schema = StructType([
    StructField("DR_NO", IntegerType()),
    StructField("Date Rptd", StringType()),
    StructField("DATE OCC", StringType()),
    StructField("TIME OCC", IntegerType()),
    StructField("AREA", IntegerType()),
    StructField("AREA NAME", StringType()),
    StructField("Rpt Dist No", IntegerType()),
    StructField("Part 1-2", IntegerType()),
    StructField("Crm Cd", IntegerType()),
    StructField("Crm Cd Desc", StringType()),
    StructField("Mocodes", StringType()),
    StructField("Vict Age", IntegerType()),
    StructField("Vict Sex", StringType()),
    StructField("Vict Descent", StringType()),
    StructField("Premis Cd", IntegerType()),
    StructField("Premis Desc", StringType()),
    StructField("Weapon Used Cd", IntegerType()),
    StructField("Weapon Desc", StringType()),
    StructField("Status", StringType()),
    StructField("Status Descent", StringType()),
    StructField("Crm Cd 1", IntegerType()),
    StructField("Crm Cd 2", IntegerType()),
    StructField("Crm Cd 3", IntegerType()),
    StructField("Crm Cd 4", IntegerType()),
    StructField("LOCATION", StringType()),
    StructField("Cross Street", StringType()),
    StructField("LAT", DoubleType()),
    StructField("LON", DoubleType()),
])

# Convert dollar value to float
def money_to_int(x):
    if (x=="---"): return 0
    vals = x.split('$')[1].split(',')
    vals[1] = vals[1].split(' ')[0]
    res = ''.join(vals)
    return int(res)

money_to_int_udf = udf(money_to_int)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Create sedona context
sedona = SedonaContext.create(spark)

start = time.time()

# Read census data for 2020
# Read the file from s3
geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson"
blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(geojson_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")

# Formatting magic
flattened_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type")

# Read income for 2021
income_df = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_income_2021.csv",
    header=True,
    schema=income_schema,
    sep=";"
)

# Convert dollar values to integers
income_df = income_df.withColumn("median_income",money_to_int_udf(col("Est_med_income"))).drop("Est_med_income")

# Read crime data for period 2020-
crime_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", \
    header=True, \
    schema=crime_schema)

# Exclude data that don't belong to years 2020 and 2021
# Also exclude data in the null island
crime_df.withColumn("year",F.year(F.to_timestamp(col("DATE OCC"), "yyyy MMM dd hh:mm:ss a")))\
    .filter((col("year")==2020) | (col("year")==2021))\
    .drop("year")\
    .filter((col("LON")==0) & (col("LAT")==0))

# Data loading and preprocessing is over
# Perform main computatiom
# Join census blocks with income per zip code
census_income = flattened_df.join(income_df, flattened_df.ZCTA20==income_df.Zip_code)\
    .select("COMM","HOUSING20","POP20","median_income")\
    .withColumn("total_income",col("median_income")*col("HOUSING20"))\
    .filter(col("POP20")!=0)\
    .drop("HOUSING20","median_income")

# Calculate income per capita per area
income_per_area = census_income.groupBy("COMM")\
    .agg(round(sum("total_income")/sum("POP20"),2).alias("Per Capita Income"))\
    .na.replace("", "Los Angeles County", subset=["COMM"])\
    .withColumnRenamed("COMM", "COMM_name")

# Aggregate areas over the geometry value
LA_areas = flattened_df.filter(col("CITY") == "Los Angeles") \
                .groupBy("COMM") \
                .agg(ST_Union_Aggr("geometry").alias("geometry"),sum("POP20").alias("Population"))

# Find the area for each crime
join_crime_area = crime_df.join(LA_areas, ST_Within(ST_Point(crime_df.LON, crime_df.LAT), LA_areas.geometry), "inner")\
    .select("COMM","DR_NO","Population")

# Aggregate crimes over areas to get average crime per person and area
crimes_per_person_x_area = join_crime_area.groupBy("COMM")\
    .agg((1000*count("DR_NO")/sum("Population")).alias("Crimes per area per 1K people"))\
    .na.replace("", "Los Angeles County", subset=["COMM"])

# Combine average crimes per person with income per person for each area
result = crimes_per_person_x_area.join(income_per_area, crimes_per_person_x_area.COMM==income_per_area.COMM_name).drop("COMM_name")
result.show(10,truncate=False)

results_top10 = result.orderBy("Per Capita Income",ascending=False)
results_bottom10 = result.orderBy("Per Capita Income",ascending=True)
results_top10.show(10)
results_bottom10.show(10)

end = time.time()
print("Elapsed time: ",end-start)
#result.explain(mode="formatted")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-----------------+-----------------------------+-----------------+
# |COMM             |Crimes per area per 1K people|Per Capita Income|
# +-----------------+-----------------------------+-----------------+
# |Toluca Terrace   |0.7363770250368189           |25786.81         |
# |Elysian Park     |0.21235931195582927          |26141.35         |
# |Longwood         |0.26062027625749284          |20725.21         |
# |Green Meadows    |0.04729921483303377          |11848.86         |
# |Cadillac-Corning |0.1643115346697338           |33043.29         |
# |Lincoln Heights  |0.03406690740614567          |18288.88         |
# |Van Nuys         |0.01106941630967799          |20630.62         |
# |Gramercy Place   |0.09433072351664937          |23247.01         |
# |Faircrest Heights|0.2745744096650192           |31042.24         |
# |Boyle Heights    |0.01272070421818552          |14566.39         |
# +-----------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# +-------------------+-----------------------------+-----------------+
# |               COMM|Crimes per area per 1K people|Per Capita Income|
# +-------------------+-----------------------------+-----------------+
# |  Pacific Palisades|         0.047728140511645666|         87750.53|
# |   Marina Peninsula|          0.20395676116663267|         85588.53|
# |Palisades Highlands|          0.25568908207619534|         83576.89|
# |        Playa Vista|         0.061614294516327786|         81679.88|
# |            Bel Air|          0.12906556530717606|         80412.74|
# |          Brentwood|           0.0329663084327817|         72946.35|
# |      Beverly Crest|          0.08390669575432119|         69669.54|
# |  Mandeville Canyon|          0.30845157310302285|         65870.07|
# |             Venice|           0.0299007295778017|         63437.58|
# |            Carthay|          0.07102272727272728|         62780.31|
# +-------------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# +------------------+-----------------------------+-----------------+
# |              COMM|Crimes per area per 1K people|Per Capita Income|
# +------------------+-----------------------------+-----------------+
# |    Vernon Central|         0.020505669817704596|         10950.15|
# |        South Park|         0.027771606309708954|          11413.4|
# |           Central|         0.028786919223904656|         11541.45|
# |             Watts|         0.023670880083321497|         11751.34|
# |     Green Meadows|          0.04729921483303377|         11848.86|
# |Florence-Firestone|         0.021843122692820165|         12294.28|
# |   University Park|          0.03883042752300703|         12374.62|
# |     Vermont Vista|         0.025004375765759007|         12434.68|
# |Century Palms/Cove|          0.03060818462856968|         12635.49|
# |    Vermont Square|          0.13192612137203166|          13262.2|
# +------------------+-----------------------------+-----------------+
# only showing top 10 rows
#
# Elapsed time:  84.41474509239197
