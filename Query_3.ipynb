# %%
# RDD implementation

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, DoubleType, StringType

# Create spark session 
sc = SparkSession \
    .builder \
    .appName("Query 3 with RDD") \
    .getOrCreate() \
    .sparkContext

df1 = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv",
    header=False,
    quote='"',
    escape='"'
)

df2 = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv",
    header=False,
    quote='"',
    escape='"'
)

data1 = df1.rdd
data2 = df2.rdd
data = data1.union(data2)

mo_df = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt",
    header=False,
    quote='"',
    escape='"'
)

mo_codes = mo_df.rdd
mo_codes = mo_codes.map(lambda x: x[0].split(" ")).map(lambda x: [x[0], ' '.join(x[1:])])

split_mos = data.filter(lambda x: x[10] is not None).flatMap(lambda x: x[10].split(" ")).filter(lambda x: x != "Mocodes")
reduce_mos = split_mos.map(lambda x: (x,1)).reduceByKey(lambda x,y: x+y)

joined_data = sorted_mos.join(mo_codes)
sorted_data = joined_data.map(lambda x: [x[1][0],(x[0], x[1][1])]).sortByKey(ascending=False)
for item in sorted_data.coalesce(1).collect():
    print(item)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# (1002900, ('0344', 'Removes vict property'))
# (548422, ('1822', 'Stranger'))
# (404773, ('0416', 'Hit-Hit w/ weapon'))
# (377536, ('0329', 'Vandalized'))
# (278618, ('0913', 'Victim knew Suspect'))
# (256188, ('2000', 'Domestic violence'))
# (219082, ('1300', 'Vehicle involved'))
# (213165, ('0400', 'Force used'))
# (177470, ('1402', 'Evidence Booked (any crime)'))
# (131229, ('1609', 'Smashed'))
# (122108, ('1309', 'Susp uses vehicle'))
# (120238, ('1202', 'Victim was aged (60 & over) or blind/physically disabled/unable to care for self'))
# (120159, ('0325', 'Took merchandise'))
# (118073, ('1814', 'Susp is/was current/former boyfriend/girlfriend'))
# (116763, ('0444', 'Pushed'))
# (115589, ('1501', 'Other MO (see rpt)'))
# (113609, ('1307', 'Breaks window'))
# (105665, ('0334', 'Brandishes weapon'))
# (93426, ('2004', 'Suspect is homeless/transient'))
# (83562, ('0432', 'Intimidation'))
# (81230, ('0342', 'Multi-susps overwhelm'))
# (81036, ('0421', 'Threaten to kill'))
# (78910, ('0906', 'Gangs'))
# (77442, ('0429', 'Vict knocked to ground'))
# (76688, ('1813', 'Susp is/was current/former spouse/co-habitant'))
# (75529, ('0377', "Takes vict's identification/driver license"))
# (72398, ('0321', 'Ransacked'))
# (71874, ('1606', 'Open/unlocked'))
# (70142, ('0448', 'Grabbed'))
# (68012, ('1607', 'Pried'))
# (67791, ('0358', 'Forces Entry'))
# (67324, ('1251', 'Victim was a student'))
# (64413, ('0352', "Took Victim's clothing or jewelry"))
# (62226, ('0446', 'Suspect swung fist'))
# (62021, ('0100', 'Suspect Impersonate'))
# (54810, ('0930', "Unauthorized use of victim's credit/debit card or number"))
# (49317, ('0417', 'Kicked'))
# (49182, ('0443', 'Threaten to harm victim (other than kill)'))
# (46968, ('1601', 'Bodily Force'))
# (45655, ('0319', 'Profanity Used'))
# (44327, ('1414', 'Photographs'))
# (44178, ('0302', 'Aimed gun'))
# (42072, ('1218', 'Victim was Homeless/Transient'))
# (41926, ('0385', 'Suspect removed parts from vehicle'))
# (41809, ('1259', 'Victim is 14 years old thru 17 years old'))
# (38316, ('0216', 'Suspect wore hood/hoodie'))
# (37298, ('1100', 'Shots Fired'))
# (37019, ('0408', 'Choked/uses choke hold/Strangulation'))
# (34614, ('0305', 'Attacks from rear'))
# (34255, ('1310', 'Victim in vehicle'))
# (33283, ('1243', 'Co-habitants'))
# (30566, ('1258', 'Victim is 6 years old thru 13 years old'))
# (30241, ('2038', 'Restraining order in place between suspect and victim'))
# (29957, ('0603', 'Landlord/Tenant/Neighbor'))
# (29777, ('2002', 'Suspect intoxicated/drunk'))
# (29527, ('0104', 'Customer'))
# (29421, ('0447', 'Suspect threw object at victim'))
# (29175, ('0419', 'Pulled victims hair'))
# (28702, ('0445', 'Suspect swung weapon'))
# (27000, ('0910', 'Public Transit (Metrolink/Train Station'))
# (26810, ('0928', 'Forged or Fraudulent credit applications'))
# (26107, ('1602', 'Cutting Tool'))
# (25726, ('0337', 'Demands money'))
# (25628, ('0202', 'Cap/hat'))
# (25597, ('0411', 'Cut/stabbed'))
# (25369, ('0394', 'Susp takes UPS'))
# (25329, ('0355', 'Demanded property other than money'))
# (25175, ('1420', 'Video surveillance booked/available'))
# (24253, ('0361', 'Suspect is neighbor'))
# (23955, ('0346', 'Snatch property and runs'))
# (23954, ('0522', 'Touched'))
# (23408, ('1407', 'Bullets/Casings'))
# (23159, ('0602', 'Family'))
# (23045, ('1302', "Suspect forced way into victim's vehicle"))
# (21610, ('0929', "Unauthorized use of victim's bank account information"))
# (21149, ('0701', 'THEFT: Trick or Device'))
# (21045, ('1817', 'Acquaintance'))
# (20668, ('1206', 'Under influence drugs/liquor'))
# (18583, ('0922', 'ATM Theft with PIN number'))
# (16895, ('0430', 'Vict shot'))
# (16863, ('2032', 'Victim left property unattended'))
# (16325, ('0360', 'Suspect is Other Family Member'))
# (16306, ('0923', 'Stolen/Forged Checks (Personal Checks)'))
# (15869, ('1212', 'LA Police Officer'))
# (15613, ('0500', 'Sex related acts'))
# (15529, ('0311', 'Graffiti'))
# (15259, ('0561', "Suspect is Victim's Son"))
# (15199, ('0371', 'Gang affiliation questions asked/made gang statement'))
# (15085, ('1906', 'Harrassing E-Mail/Text Message/Other Electronic Communications'))
# (14545, ('1221', 'Missing Clothing/Jewelry'))
# (14482, ('1236', 'Clerk/Employer/Owner'))
# (13327, ('1605', 'Lock slip/key/pick'))
# (13294, ('0527', 'Actual Intercourse'))
# (13292, ('0917', "Victim's Employment"))
# (13049, ('0401', 'Bit'))
# (12641, ('0601', 'Business'))
# (12437, ('1810', 'Susp is/was roommate'))
# (12104, ('0345', 'Riding bike'))
# (12100, ('0356', 'Suspect spits on victim'))
# (11889, ('1241', 'Spouse'))
# (11714, ('1266', 'Victim was security guard'))
# (11673, ('0314', 'Hot Prowl'))
# (11309, ('0397', 'Cut lock (to bicycle'))
# (11083, ('0800', 'BUNCO'))
# (10988, ('1608', 'Removed'))
# (10951, ('0945', 'Estes Robbery'))
# (10831, ('2024', 'Suspect was Juvenile'))
# (10761, ('0378', 'Brings own bag'))
# (10759, ('0554', "Suspect is Victim's Brother"))
# (10437, ('1816', 'Suspect is/was known gang member'))
# (9971, ('0326', 'Used driver'))
# (9856, ('0450', 'Suspect shot at victim (no hits)'))
# (9824, ('1821', 'Spouse'))
# (9809, ('1820', 'Friend'))
# (9593, ('0552', "Suspect is Victim's Father"))
# (9497, ('1257', 'Victim is Newborn-5 years old'))
# (9466, ('0431', 'Sprayed with chemical'))
# (9204, ('2021', 'Suspect was Aged (60+over)'))
# (8802, ('1313', 'Suspect exits vehicle and attacks pedestrian'))
# (8668, ('1210', 'Professional (doctor'))
# (8556, ('0312', 'Gun in waistband'))
# (8468, ('0369', 'Suspect speaks spanish'))
# (8387, ('0340', 'Suspect follows victim/follows victim home'))
# (8327, ('0449', 'Put a weapon to body'))
# (8046, ('0553', "Suspect is Victim's Mother"))
# (7924, ('0924', 'Stolen/Forged Checks (Business Checks)'))
# (7882, ('1912', 'Threatening E-mail/Text Messages'))
# (7643, ('0422', 'Threaten Victims family'))
# (7407, ('1415', 'Rape Kit'))
# (7300, ('0919', 'Road Rage'))
# (7128, ('0370', 'Frisks victim/pats down victim/searches victim'))
# (6989, ('1419', 'Firearm booked as evidence'))
# (6764, ('0354', 'Suspect takes car keys'))
# (6709, ('0935', 'Misc. Stolen/Forged documents'))
# (6643, ('1803', "Susp is/was victim's employee"))
# (6532, ('0209', 'Mask'))
# (6523, ('2003', 'Suspect was 5150/mentally disabled'))
# (6503, ('1815', 'Susp was student'))
# (6290, ('0529', 'Indecent Exposure'))
# (6227, ('0336', 'Chain snatch'))
# (6198, ('0327', 'Used lookout'))
# (6051, ('2034', 'Victim was asleep/unconscious'))
# (5953, ('1240', 'Vehicle occupant/Passenger'))
# (5653, ('0562', "Suspect is Victim's Daughter"))
# (5589, ('0907', 'Narcotics (Buy-Sell-Rip)'))
# (5537, ('0515', 'Put hand'))
# (5533, ('1312', 'Suspect follows victim in vehicle'))
# (5407, ('0503', 'Fondle victim'))
# (5293, ('0537', "Suspect removes victim's clothing"))
# (5277, ('0551', 'Suspect touches victim genitalia/genitals over clothing'))
# (5267, ('0510', 'Kissed victims body/face'))
# (5169, ('2033', 'Victim refused to cooperate w/investigation'))
# (5165, ('0386', 'Suspect removed property from trunk of vehicle'))
# (5099, ('2001', 'Suspect on drugs'))
# (5016, ('0903', 'Hatred/Prejudice'))
# (5006, ('2028', 'Suspect was Repeat/known shoplifter'))
# (4894, ('0330', 'Victims vehicle taken'))
# (4771, ('0533', 'Consentual Sex'))
# (4700, ('0359', 'Made unusual statement'))
# (4613, ('0605', 'Traffic Accident/Traffic related incident'))
# (4581, ('0916', 'Forced theft of vehicle (Car-Jacking)'))
# (4567, ('0324', 'Takes money from register'))
# (4384, ('1612', 'Punched/Pulled Door Lock'))
# (4374, ('1802', "Susp is/was victim's co-worker"))
# (4262, ('0418', 'Kidnapped'))
# (4241, ('0349', 'Takes mail'))
# (3930, ('0528', 'Masturbate'))
# (3927, ('1409', 'Clothes'))
# (3849, ('0555', "Suspect is Victim's Sister"))
# (3705, ('0206', 'Gloves'))
# (3346, ('1019', 'Money'))
# (3322, ('1276', 'Pregnant'))
# (3287, ('0507', 'Forced to orally copulate suspect'))
# (3216, ('0309', 'Drive-by shooting'))
# (3105, ('0519', 'Sodomy'))
# (3070, ('1275', 'Vacant Residence/Building'))
# (2950, ('1242', 'Parent'))
# (2942, ('0531', 'Suspect made sexually suggestive remarks'))
# (2939, ('1823', 'Brief encounter/Date'))
# (2854, ('1824', 'Classmate'))
# (2818, ('1403', 'Fingerprints'))
# (2752, ('1237', 'Victim was customer'))
# (2682, ('0536', 'Suspect removes own clothing'))
# (2603, ('0512', 'Orally copulated victim'))
# (2589, ('2052', 'Suspect was passenger on train'))
# (2585, ('0420', 'Searched'))
# (2541, ('0558', "Suspect is Victim's Uncle"))
# (2535, ('0556', "Suspect is Victim's Step-Father"))
# (2492, ('0390', 'Purse snatch'))
# (2456, ('1238', 'Victim was physically disabled'))
# (2449, ('1270', 'Victim was gang member'))
# (2440, ('1203', 'Victim of crime past 12 months'))
# (2410, ('1913', 'Suspect meets victim on internet/chatroom'))
# (2407, ('0516', 'Reached climax/ejaculated'))
# (2379, ('1223', 'Riding bike'))
# (2374, ('0316', 'Makes victim give money'))
# (2338, ('0347', 'Stalks vict'))
# (2308, ('0380', 'Distracts Victim'))
# (2305, ('0353', 'Weapon Concealed'))
# (2285, ('2049', 'Victim was passenger on bus'))
# (2284, ('0315', 'Jumped counter/goes behind counter'))
# (2282, ('1311', 'Victim removed from vehicle'))
# (2272, ('2051', 'Suspect was passenger on bus'))
# (2260, ('1900', 'Auction Fraud/eBay/cragslist'))
# (2183, ('1701', 'Elder Abuse/Physical'))
# (2166, ('1267', 'Home under construction'))
# (2155, ('0532', 'Suspect undressed victim'))
# (2123, ('1000', 'Suspects offers/solicits'))
# (1950, ('0213', 'Ski mask'))
# (1946, ('1216', 'Sales'))
# (1918, ('1268', 'Victim was 5150/Mental Illness'))
# (1901, ('9999', 'Indistinctive MO'))
# (1893, ('0389', 'Knock-knock'))
# (1847, ('1205', 'On Vacation/Tourist'))
# (1837, ('0908', 'Prostitution'))
# (1829, ('1305', 'Victim forced into vehicle'))
# (1796, ('2055', 'Victim targeted based on Race/Ethnicity/Ancestry'))
# (1793, ('1252', 'Victim was a street vendor'))
# (1788, ('1278', 'Victim was Uber/Lyft driver'))
# (1729, ('0375', 'Removes cash register'))
# (1693, ('1222', 'Victim was gay'))
# (1677, ('2048', 'Victim was on transit platform'))
# (1628, ('0925', "Stolen/Forged Checks (Cashier's Checks)"))
# (1619, ('2050', 'Victim was passenger on train'))
# (1608, ('0940', 'Met online/Chat Room/on Party Line'))
# (1578, ('0931', 'Counterfeit or forged real estate documents'))
# (1556, ('0914', 'Other Felony'))
# (1507, ('0545', 'Male Victim of sexual assault'))
# (1490, ('0509', 'Hugged'))
# (1466, ('0382', 'Removed money/property from safe'))
# (1460, ('1916', 'Victim paid by wire transfer'))
# (1443, ('1801', "Susp is/was mother's boyfriend"))
# (1413, ('1804', "Susp is/was victim's employer"))
# (1408, ('0409', 'Cover mouth w/hands'))
# (1407, ('0381', 'Suspect apologizes'))
# (1406, ('0404', 'Bomb Threat'))
# (1401, ('0306', 'Crime on upper floor'))
# (1361, ('1811', "Susp is/was victim's teacher/coach"))
# (1357, ('0363', 'Home invasion'))
# (1348, ('1818', 'Caretaker/care-giver/nanny'))
# (1343, ('0926', 'Forged or Telephonic Prescription'))
# (1330, ('2047', 'Victim was injured requiring transportation away from scene for medical reasons'))
# (1322, ('0308', 'Demands jewelry'))
# (1310, ('0387', 'Weapon (other than gun) in waistband'))
# (1295, ('1914', 'Unauthorized access to computer system'))
# (1290, ('0207', 'Handkerchief'))
# (1254, ('1317', 'Victim exiting their vehicle'))
# (1208, ('1413', 'Paint'))
# (1199, ('1915', 'Internet Extortion'))
# (1189, ('0304', 'Ate/drank on premises'))
# (1175, ('1262', 'Raped while unconscious'))
# (1153, ('1217', "Teenager(Use if victim's age is unknown)"))
# (1141, ('2014', 'Suspect was Uber/Lyft driver'))
# (1140, ('0520', 'Solicited/offered immoral act'))
# (1128, ('1306', 'Victim parking'))
# (1108, ('0943', 'Human Trafficking'))
# (1107, ('1022', 'Ride'))
# (1105, ('0413', 'Drugged'))
# (1105, ('1234', 'Bar Customer'))
# (1071, ('2007', 'Suspect was gay'))
# (1071, ('1008', 'Cigarette'))
# (1066, ('1256', 'Patron'))
# (1059, ('1026', 'Use the phone or toilet'))
# (1050, ('1215', 'Prostitute'))
# (1044, ('0526', 'Utilized Condom'))
# (1034, ('0514', 'Pornography'))
# (1028, ('1231', 'Taxi Driver'))
# (996, ('1253', 'Bus Driver'))
# (992, ('1261', 'Victim was mentally challenged/mentally disabled'))
# (984, ('1213', 'LA Fireman'))
# (962, ('1281', 'Victim was Pistol-whipped'))
# (959, ('1610', 'Tunneled'))
# (957, ('0406', 'Brutal Assault'))
# (925, ('0112', 'Police'))
# (915, ('0351', 'Disabled Security'))
# (913, ('1247', 'Opening business'))
# (910, ('1514', 'Bias: AntI-Black or African American'))
# (910, ('1805', 'Susp is/was fellow gang member'))
# (908, ('0374', 'Gang signs/threw gang signs using hands'))
# (904, ('0341', 'Makes vict lie down'))
# (903, ('0339', 'Disables video camera'))
# (900, ('1227', 'Delivery person'))
# (874, ('2060', 'Victim inside tent'))
# (871, ('0501', 'Susp ejaculated outside victim'))
# (867, ('2035', 'Racial slurs'))
# (861, ('0407', 'Burned Victim'))
# (832, ('0426', 'Twisted arm'))
# (814, ('1020', 'Narcotics'))
# (800, ('1271', 'Victim was Law Enforcement (not LAPD)'))
# (787, ('1401', 'Blood Stains'))
# (773, ('2036', 'Hate-related language'))
# (770, ('0538', 'Suspect fondles self'))
# (761, ('2018', 'Cannabis related'))
# (736, ('2054', 'Victim targeted based on sexual orientation'))
# (729, ('1017', 'Information'))
# (727, ('1304', 'Stopped victim vehicle by flagging down'))
# (715, ('1819', 'Common-law Spouse'))
# (708, ('0921', 'Hate Incident'))
# (708, ('0942', 'Party/Flier party/Rave Party'))
# (707, ('2006', 'Suspect was transgender'))
# (702, ('1308', 'Drives by and snatches property'))
# (701, ('0338', 'Disables Telephone'))
# (676, ('2053', 'Victim targeted based on religion'))
# (672, ('1273', 'Home was being fumigated'))
# (645, ('0513', 'Photographed victim'))
# (642, ('0368', 'Suspect speaks foreign language'))
# (635, ('2041', 'Harassment via Social Media'))
# (628, ('0508', 'Hit victim prior'))
# (625, ('0542', 'Orders victim to undress'))
# (624, ('0911', 'Revenge'))
# (617, ('1316', 'Victim entering their vehicle'))
# (617, ('1536', 'Bias: Anti-Gay (Male)'))
# (609, ('1528', 'Bias: Anti-Jewish'))
# (609, ('0540', "Suspect puts finger(s) in victim's rectum"))
# (608, ('0201', 'Bag'))
# (603, ('2040', 'Threats via Social Media'))
# (600, ('0373', 'Physicall disabled/in wheelchair'))
# (590, ('1239', 'Transgender'))
# (587, ('1318', 'Suspect follows victim home'))
# (575, ('0372', 'Photographed victim/took pictures of victim'))
# (574, ('1611', 'Shaved Key'))
# (569, ('1809', 'Susp is/was rival gang member'))
# (558, ('0335', 'Cases location'))
# (554, ('2029', 'Victim used profanity'))
# (548, ('1214', 'Banking'))
# (547, ('1812', 'Susp is/was foster parent/sibling'))
# (545, ('1009', 'Directions'))
# (543, ('1225', 'Stop sign/light'))
# (539, ('0332', 'Mailbox Vandalism'))
# (534, ('0307', 'Defecated/urinated'))
# (519, ('0398', 'Roof access (remove A/C'))
# (518, ('1018', 'Liquor'))
# (509, ('1516', 'Bias: Anti-Hispanic or Latino'))
# (505, ('0927', 'Fraudulent or forged school loan'))
# (496, ('2005', 'Suspect uses wheelchair'))
# (495, ('1702', 'Elder Abuse/Financial'))
# (490, ('0505', 'Forced to fondle suspect'))
# (489, ('0559', "Suspect is Victim's Aunt"))
# (480, ('0410', "Covered victim's face"))
# (475, ('0121', 'DWP/Gas Company/Utility worker'))
# (466, ('0212', 'Nude/partly nude'))
# (460, ('1902', 'Credit Card Fraud/Theft of services via internet'))
# (455, ('0424', 'Tore clothes off victim'))
# (453, ('1416', 'Saliva'))
# (453, ('0550', 'Suspect licks victim'))
# (450, ('0120', 'Social Security/Medicare'))
# (449, ('1314', 'Victim loading vehicle'))
# (447, ('0383', 'Suspect entered during open house/party/estate/yard sale'))
# (446, ('0303', 'Ambushed'))
# (434, ('1808', 'Susp is/was other religious confidant'))
# (433, ('0357', 'Cuts or breaks purse strap'))
# (432, ('0403', 'Bomb Threat'))
# (429, ('0534', 'Suspect in vehicle nude/partially nude'))
# (419, ('0915', 'Parolee'))
# (413, ('1265', 'Mailbox'))
# (405, ('2037', 'Temporary/Vacation rental (AirBnB'))
# (404, ('0934', "Suspect uses victim's identity when receiving a citation"))
# (404, ('0541', "Suspect puts object(s) in victim's rectum"))
# (401, ('0365', 'Takeover robbery'))
# (372, ('0322', 'Smashed display case'))
# (371, ('1204', 'Moving'))
# (368, ('1908', 'Identity Theft via computer'))
# (358, ('0506', 'Forced to masturbate suspect'))
# (357, ('2027', 'Suspect was Pregnant'))
# (353, ('1604', 'Lock Box'))
# (349, ('0518', 'Simulated intercourse'))
# (349, ('1408', 'Bite Marks'))
# (349, ('1260', 'Deaf/Hearing Impaired'))
# (342, ('1315', 'Victim unloading vehicle'))
# (340, ('0405', 'Bound'))
# (335, ('0399', 'Vehicle to Vehicle shooting'))
# (332, ('0918', 'Career Criminal'))
# (329, ('0947', 'Motorized Rental Scooter/Bike (Bird'))
# (327, ('0343', 'Orders vict to rear room'))
# (317, ('0384', 'Suspect removed drugs from location'))
# (310, ('0366', 'Ordered vict to open safe'))
# (308, ('0504', 'Forced to disrobe'))
# (303, ('1903', 'Cyberstalking (Stalking using internet to commit the crime)'))
# (303, ('0391', 'Used demand note'))
# (302, ('1230', 'Postal employee'))
# (302, ('1013', 'Food'))
# (296, ('0433', 'Makes victim kneel'))
# (294, ('0379', 'Turns off lights/electricity'))
# (292, ('1901', 'Child Pornography/In possession of/Via computer'))
# (287, ('1219', 'Nude'))
# (280, ('1405', 'Left Note'))
# (278, ('1028', 'Suspect solicits time of day'))
# (266, ('0110', 'Involved in traffic/accident'))
# (264, ('0415', 'Handcuffed/Metal'))
# (264, ('2009', 'Suspect was Inmate/Incarcerated'))
# (262, ('0301', 'Escaped on (used) transit train'))
# (262, ('0217', 'Uniform'))
# (261, ('0442', 'Active Shooter/Armed person who has used deadly physical force on other'))
# (259, ('1301', 'Forced victim vehicle to curb'))
# (258, ('1027', 'Change'))
# (258, ('0933', "Suspect uses victim's identity when arrested"))
# (257, ('0101', 'Aid victim'))
# (256, ('0113', 'Renting'))
# (256, ('0200', 'Suspect wore disguise'))
# (254, ('2011', 'Vendor (street or sidewalk)'))
# (252, ('1404', 'Footprints'))
# (251, ('0549', 'Suspect ejaculates in victims mouth'))
# (243, ('0392', 'False Emergency Reporting'))
# (243, ('0114', 'Repair Person'))
# (243, ('1603', 'Knob Twist'))
# (238, ('1004', 'Assistant'))
# (237, ('0396', 'Used paper plates to disguise license number'))
# (230, ('0402', 'Blindfolded'))
# (229, ('0393', '911 Abuse'))
# (225, ('1228', 'Leaving Business Area'))
# (225, ('0310', 'Got victim to withdraw savings'))
# (224, ('0427', 'Whipped'))
# (223, ('1011', 'Employment'))
# (221, ('0543', 'Orders victim to fondle suspect'))
# (212, ('0557', "Suspect is Victim's Step-Mother"))
# (211, ('2058', 'Victim targeted based on Gender Non-conforming'))
# (207, ('1910', 'Minor solicited for sex via internet/Known minor'))
# (206, ('0423', 'Tied victim to object'))
# (202, ('2023', 'Suspect was Prostitute'))
# (202, ('0440', 'Telephone/Electric Cord'))
# (196, ('1010', 'Drink (not liquor)'))
# (195, ('1406', 'Tool Marks'))
# (193, ('0218', 'Wig'))
# (184, ('1410', 'Gun Shot Residue'))
# (184, ('0511', 'Masochism/bondage'))
# (182, ('0328', 'Used toilet'))
# (181, ('1510', 'Bias: Anti-Transgender'))
# (181, ('0364', 'Suspect is babysitter'))
# (174, ('0317', 'Pillowcase/suitcase'))
# (172, ('2020', 'Mistreatment of animal'))
# (172, ('2019', 'Theft of animal (non-livestock)'))
# (171, ('1272', 'Victim was at/leaving medical/retail/non-retail cannabis location'))
# (170, ('0395', 'Murder/Suicide'))
# (166, ('1248', 'Closing business'))
# (165, ('0362', 'Suspect attempts to carry victim away'))
# (161, ('0451', 'Suffocation'))
# (160, ('0117', 'Salesman'))
# (160, ('2030', 'Victim used racial slurs'))
# (157, ('1520', 'Bias: Anti-White'))
# (153, ('1513', 'Bias: Anti-Asian'))
# (153, ('1220', 'Partially Nude'))
# (152, ('1911', 'Theft of computer data'))
# (151, ('0320', 'Quiet polite'))
# (151, ('0439', 'Tape/Electrical etc...'))
# (149, ('0220', 'Suspect wore motorcycle helmet'))
# (149, ('0525', 'Urinated'))
# (146, ('0323', 'Smoked on premises'))
# (145, ('1277', 'Gardner'))
# (143, ('1226', 'Catering Truck Operator'))
# (142, ('0204', 'Clothes of opposite sex'))
# (140, ('1233', 'Bank'))
# (138, ('1412', 'Jewelry'))
# (136, ('1209', 'Salesman'))
# (134, ('0437', 'Flexcuffs/Plastic Tie'))
# (133, ('1519', 'Bias: Anti-Other Race/Ethnicity/Ancestry'))
# (133, ('0521', 'Tongue or mouth to anus'))
# (133, ('0938', 'Animal Neglect'))
# (131, ('2031', 'Victim used hate-related language'))
# (131, ('1907', 'Hate Crime materials/printouts/e-mails'))
# (123, ('0912', 'Insurance'))
# (122, ('0376', 'Makes victim kneel'))
# (119, ('2042', 'Victim staying at short-term vacation rental'))
# (119, ('0414', 'Gagged'))
# (117, ('0560', "Suspect is Victim's Guardian"))
# (113, ('0313', 'Hid in building'))
# (112, ('1274', 'Victim was Inmate/Incarcerated'))
# (109, ('1211', 'Public Official'))
# (109, ('0105', 'Delivery'))
# (108, ('0388', 'Suspect points laser at plane/helicopter'))
# (108, ('1806', "Susp is/was father's girlfriend"))
# (108, ('1235', 'Bisexual/sexually oriented towards both sexes'))
# (103, ('0118', 'Seeking someone'))
# (103, ('0438', 'Rope/Cordage'))
# (99, ('1201', 'Absent-advertised in paper'))
# (99, ('1807', 'Susp is/was priest/pastor'))
# (98, ('0208', 'Halloween mask'))
# (97, ('0348', 'Takeover other'))
# (97, ('0547', 'Suspect force vict to bathe/clean/wipe'))
# (95, ('2056', 'Victim targeted based on gender'))
# (94, ('0523', 'Unable to get erection'))
# (93, ('1001', 'Aid for vehicle'))
# (92, ('0412', 'Disfigured'))
# (91, ('0215', 'Unusual clothes'))
# (91, ('0902', 'Political Activity'))
# (90, ('0932', "Suspect uses victim's identity in reporting a traffic collision"))
# (88, ('1539', 'Bias: Anti-Lesbian/Gay/Bisexual or Transgender (Mixed Group)'))
# (88, ('1255', 'Followed Transit System'))
# (86, ('1417', 'Semen'))
# (84, ('0539', "Suspect puts hand in victim's rectum"))
# (82, ('1002', 'Amusement'))
# (82, ('0535', "Suspect asks minor's name"))
# (81, ('0425', 'Tortured'))
# (81, ('1303', 'Hid in rear seat'))
# (80, ('2043', 'Victim is owner of short-term vacation rental'))
# (79, ('0946', 'Gang Feud'))
# (77, ('0436', 'Clothing'))
# (77, ('0109', 'Inspector'))
# (76, ('0318', 'Prepared exit'))
# (75, ('1021', 'Repair'))
# (74, ('0530', 'Used lubricant'))
# (72, ('0205', 'Earring'))
# (71, ('1007', 'Candy'))
# (68, ('0102', 'Blind'))
# (66, ('2017', 'Suspect was MTA Bus Driver'))
# (65, ('2044', 'Suspect staying at short-term vacation rental'))
# (64, ('1538', 'Bias: Anti-Lesbian'))
# (62, ('0331', 'Mailbox Bombing'))
# (62, ('2046', 'Suspect damaged property equal to or exceeding $25'))
# (61, ('0122', 'Contractor'))
# (61, ('0115', 'Returning stolen property'))
# (61, ('0203', 'Cloth (with eyeholes)'))
# (60, ('1224', 'Drive-through (not merchant)'))
# (60, ('0944', 'Bait Operation'))
# (60, ('2026', 'Suspect was Deaf/hearing impaired'))
# (59, ('0909', 'Ritual/Occult'))
# (59, ('1245', 'Victim was forced into residence'))
# (57, ('1101', 'Shots Fired (Animal) - Animal Services'))
# (55, ('0350', "Concealed victim's body"))
# (54, ('0901', 'Organized Crime'))
# (53, ('2010', 'Suspect was Jailer/Police Officer'))
# (53, ('0211', 'Shoes'))
# (53, ('1012', 'Find a job'))
# (52, ('1229', 'Making bank drop'))
# (52, ('0106', 'Doctor'))
# (51, ('1905', 'Destruction of computer data'))
# (51, ('0119', 'Sent by owner'))
# (50, ('0920', 'Homeland Security'))
# (50, ('0904', 'Strike/Labor Troubles'))
# (49, ('0546', 'Susp instructs vict to make certain statements'))
# (49, ('0563', 'Fetish'))
# (47, ('0333', 'Used hand held radios'))
# (46, ('1279', 'Victim was Foster child'))
# (45, ('0544', 'Orders victim to fondle self'))
# (44, ('2059', 'Vict rptd sexual assault at time of arst for unrelated incident'))
# (44, ('0219', 'Mustache-Fake'))
# (43, ('0502', 'Fecal Fetish'))
# (43, ('0103', 'Physically disabled'))
# (42, ('0435', 'Chain'))
# (42, ('1254', 'Train Operator'))
# (42, ('2015', 'Suspect was Foster child'))
# (41, ('1512', 'Bias: Anti-Arab'))
# (40, ('1015', 'Gift'))
# (39, ('1909', 'Introduction of virus or contaminants into computer system/program'))
# (39, ('1232', 'Bank'))
# (38, ('1208', 'Victim was undocumented alien'))
# (38, ('1244', 'Victim was forced into business'))
# (38, ('0517', 'Sadism/Sexual gratification obtained by infliction of physical or mental pain on others'))
# (38, ('0214', 'Stocking'))
# (37, ('1532', 'Bias: Anti-Other Religion'))
# (36, ('2057', 'Victim targeted based on disability'))
# (36, ('0441', 'Wire'))
# (35, ('1411', 'Hair'))
# (34, ('0428', 'Dismembered'))
# (34, ('1207', 'Hitchhiker'))
# (34, ('1526', 'Bias: Anti-Islamic (Muslim)'))
# (32, ('1418', 'Skeleton/Bones'))
# (29, ('2008', 'In possession of a Ballistic vest'))
# (29, ('1280', 'Victim was Foster parent'))
# (28, ('0434', 'Bed Sheets/Linens'))
# (27, ('0107', 'God'))
# (27, ('0210', 'Make up (males only)'))
# (26, ('1904', 'Denial of computer services'))
# (26, ('1531', 'Bias: Anti-Other Christian'))
# (25, ('2025', 'Suspect was Bisexual'))
# (24, ('2012', 'Suspect was costumed character (e.g.'))
# (24, ('0123', 'Gardener/Tree Trimmer'))
# (24, ('1507', 'Bias : Anti-female'))
# (23, ('1014', 'Game'))
# (23, ('0524', 'Underwear Fetish'))
# (22, ('1517', 'Bias: Anti-Multiple Races (Group)'))
# (21, ('0937', 'Cock Fighting'))
# (21, ('2039', 'Victim was costumed character (e.g.'))
# (20, ('1509', 'Bias: Anti-Gender non-conforming'))
# (18, ('0108', 'Infirm'))
# (16, ('1506', 'Bias: Physical disability'))
# (16, ('0939', 'Animal Hoarding'))
# (16, ('1016', 'Hold for safekeeping'))
# (15, ('0936', 'Dog Fighting'))
# (15, ('0905', 'Terrorist Group'))
# (14, ('0604', 'Reproductive Health Services/Facilities'))
# (14, ('1269', 'Victim was armored car driver'))
# (13, ('1523', 'Bias: Anti-Catholic'))
# (13, ('1025', 'Train'))
# (13, ('1515', 'Bias: Anti-Citizenship Status'))
# (13, ('1505', 'Bias: Mental Disability'))
# (12, ('2013', 'Tour Bus/Van Operator'))
# (12, ('1535', 'Bias: Anti-Bisexual'))
# (12, ('1264', 'Pipeline'))
# (10, ('1527', "Bias: Anti-Jehovah's Witness"))
# (8, ('2022', 'Suspect was Hitchhiker'))
# (8, ('1005', 'Audition'))
# (8, ('2045', 'Suspect is owner of short-term vacation rental'))
# (7, ('1525', 'Bias: Anti-Hindu'))
# (7, ('0116', 'Satan'))
# (7, ('1508', 'Bias: Anti-male'))
# (6, ('1006', 'Bless'))
# (6, ('1522', 'Bias: Anti-Buddhist'))
# (6, ('1530', 'Bias: Anti-Multiple Religions Group'))
# (6, ('1024', 'Teach'))
# (6, ('0367', 'Was Transit Patrol'))
# (5, ('1511', 'Bias: Anti-American/Alaskan Native'))
# (4, ('1023', 'Subscriptions'))
# (4, ('2016', 'Suspect was Train Operator'))
# (4, ('1003', 'appraise'))
# (4, ('0941', 'Non-Revocable Parole (NRP)'))
# (3, ('1537', 'Bias: Anti-Heterosexual'))
# (3, ('1518', 'Bias: Anti-Native Hawaiian or Other Pacific Islander'))
# (3, ('1533', 'Bias: Anti-Protestant'))
# (2, ('1263', 'Agricultural Target'))
# (1, ('1521', 'Bias: Anti-Atheism/Agnosticism'))
# (1, ('1524', 'Bias: Anti-Eastern Orthodox (Russian/Greek/Other)'))
# (1, ('0548', 'Suspect gives victim douche/enema'))
# (1, ('1534', 'Bias: Anti-Sikh'))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, DoubleType, StringType
from pyspark.sql.functions import col, instr, expr, udf
from pyspark.sql import functions as F

spark = SparkSession \
    .builder \
    .appName("Query 3 with DataFrame") \
    .getOrCreate() \

crimes_schema = StructType([
    StructField("DR_NO", IntegerType()),
    StructField("Date Rptd", StringType()),
    StructField("DATE OCC", StringType()),
    StructField("TIME OCC", IntegerType()),
    StructField("AREA", IntegerType()),
    StructField("AREA NAME", StringType()),
    StructField("Rpt Dist No", IntegerType()),
    StructField("Part 1-2", IntegerType()),
    StructField("Crm Cd", IntegerType()),
    StructField("Crm Cd Desc", StringType()),
    StructField("Mocodes", StringType()),
    StructField("Vict Age", IntegerType()),
    StructField("Vict Sex", StringType()),
    StructField("Vict Descent", StringType()),
    StructField("Premis Cd", IntegerType()),
    StructField("Premis Desc", StringType()),
    StructField("Weapon Used Cd", IntegerType()),
    StructField("Weapon Desc", StringType()),
    StructField("Status", StringType()),
    StructField("Crm Cd 1", IntegerType()),
    StructField("Crm Cd 2", IntegerType()),
    StructField("Crm Cd 3", IntegerType()),
    StructField("Crm Cd 4", IntegerType()),
    StructField("LOCATION", StringType()),
    StructField("Cross Street", StringType()),
    StructField("LAT", DoubleType()),
    StructField("LON", DoubleType()),
])

df1 = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2010_2019.csv",
    header=False,
    schema=crimes_schema,
    quote='"',
    escape='"'
)

df2 = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv",
    header=False,
    schema=crimes_schema,
    quote='"',
    escape='"'
)

data = df1.union(df2)

mo_schema = StructType([
    StructField("MO_data", StringType()),
])

mo_df = spark.read.csv(
    "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/MO_codes.txt",
    header=False,
    schema=mo_schema,
    quote='"',
    escape='"'
)

def split_mo_1(x):
    lst = x.split(" ")
    return lst[0]

def split_mo_2(x):
    lst = x.split(" ")
    return ' '.join(lst[1:])

get_mo_code = udf(split_mo_1, StringType())
get_mo_desc = udf(split_mo_2, StringType())

mo_df = mo_df.withColumn("MO_code",get_mo_code(col("MO_data"))).withColumn("MO_desc",get_mo_desc(col("MO_data"))).drop("MO_data")

# Different method, possibly slower
#joined_df = data.join(mo_df, expr("instr(Mocodes, MO_code) > 0"),"inner")
#grouped_df = joined_df.groupBy(col("MO_code"),col("MO_desc")).count()
#sorted_df = grouped_df.orderBy(col("count"),ascending=False)
#sorted_df.show(1000, truncate=False)

split_codes = data.withColumn("codes_array", F.split(F.col("Mocodes"), " ")).withColumn("code", F.explode("codes_array")).drop("codes_array")
group_codes = split_codes.groupBy(col("code")).count()
join_desc = group_codes.join(mo_df, group_codes.code==mo_df.MO_code).drop("MO_code")
result = join_desc.orderBy(col("count"),ascending=False)
result.show(1000, truncate=False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +----+-------+---------------------------------------------------------------------------------------+
# |code|count  |MO_desc                                                                                |
# +----+-------+---------------------------------------------------------------------------------------+
# |0344|1002900|Removes vict property                                                                  |
# |1822|548422 |Stranger                                                                               |
# |0416|404773 |Hit-Hit w/ weapon                                                                      |
# |0329|377536 |Vandalized                                                                             |
# |0913|278618 |Victim knew Suspect                                                                    |
# |2000|256188 |Domestic violence                                                                      |
# |1300|219082 |Vehicle involved                                                                       |
# |0400|213165 |Force used                                                                             |
# |1402|177470 |Evidence Booked (any crime)                                                            |
# |1609|131229 |Smashed                                                                                |
# |1309|122108 |Susp uses vehicle                                                                      |
# |1202|120238 |Victim was aged (60 & over) or blind/physically disabled/unable to care for self       |
# |0325|120159 |Took merchandise                                                                       |
# |1814|118073 |Susp is/was current/former boyfriend/girlfriend                                        |
# |0444|116763 |Pushed                                                                                 |
# |1501|115589 |Other MO (see rpt)                                                                     |
# |1307|113609 |Breaks window                                                                          |
# |0334|105665 |Brandishes weapon                                                                      |
# |2004|93426  |Suspect is homeless/transient                                                          |
# |0432|83562  |Intimidation                                                                           |
# |0342|81230  |Multi-susps overwhelm                                                                  |
# |0421|81036  |Threaten to kill                                                                       |
# |0906|78910  |Gangs                                                                                  |
# |0429|77442  |Vict knocked to ground                                                                 |
# |1813|76688  |Susp is/was current/former spouse/co-habitant                                          |
# |0377|75529  |Takes vict's identification/driver license                                             |
# |0321|72398  |Ransacked                                                                              |
# |1606|71874  |Open/unlocked                                                                          |
# |0448|70142  |Grabbed                                                                                |
# |1607|68012  |Pried                                                                                  |
# |0358|67791  |Forces Entry                                                                           |
# |1251|67324  |Victim was a student                                                                   |
# |0352|64413  |Took Victim's clothing or jewelry                                                      |
# |0446|62226  |Suspect swung fist                                                                     |
# |0100|62021  |Suspect Impersonate                                                                    |
# |0930|54810  |Unauthorized use of victim's credit/debit card or number                               |
# |0417|49317  |Kicked                                                                                 |
# |0443|49182  |Threaten to harm victim (other than kill)                                              |
# |1601|46968  |Bodily Force                                                                           |
# |0319|45655  |Profanity Used                                                                         |
# |1414|44327  |Photographs                                                                            |
# |0302|44178  |Aimed gun                                                                              |
# |1218|42072  |Victim was Homeless/Transient                                                          |
# |0385|41926  |Suspect removed parts from vehicle                                                     |
# |1259|41809  |Victim is 14 years old thru 17 years old                                               |
# |0216|38316  |Suspect wore hood/hoodie                                                               |
# |1100|37298  |Shots Fired                                                                            |
# |0408|37019  |Choked/uses choke hold/Strangulation                                                   |
# |0305|34614  |Attacks from rear                                                                      |
# |1310|34255  |Victim in vehicle                                                                      |
# |1243|33283  |Co-habitants                                                                           |
# |1258|30566  |Victim is 6 years old thru 13 years old                                                |
# |2038|30241  |Restraining order in place between suspect and victim                                  |
# |0603|29957  |Landlord/Tenant/Neighbor                                                               |
# |2002|29777  |Suspect intoxicated/drunk                                                              |
# |0104|29527  |Customer                                                                               |
# |0447|29421  |Suspect threw object at victim                                                         |
# |0419|29175  |Pulled victims hair                                                                    |
# |0445|28702  |Suspect swung weapon                                                                   |
# |0910|27000  |Public Transit (Metrolink/Train Station                                                |
# |0928|26810  |Forged or Fraudulent credit applications                                               |
# |1602|26107  |Cutting Tool                                                                           |
# |0337|25726  |Demands money                                                                          |
# |0202|25628  |Cap/hat                                                                                |
# |0411|25597  |Cut/stabbed                                                                            |
# |0394|25369  |Susp takes UPS                                                                         |
# |0355|25329  |Demanded property other than money                                                     |
# |1420|25175  |Video surveillance booked/available                                                    |
# |0361|24253  |Suspect is neighbor                                                                    |
# |0346|23955  |Snatch property and runs                                                               |
# |0522|23954  |Touched                                                                                |
# |1407|23408  |Bullets/Casings                                                                        |
# |0602|23159  |Family                                                                                 |
# |1302|23045  |Suspect forced way into victim's vehicle                                               |
# |0929|21610  |Unauthorized use of victim's bank account information                                  |
# |0701|21149  |THEFT: Trick or Device                                                                 |
# |1817|21045  |Acquaintance                                                                           |
# |1206|20668  |Under influence drugs/liquor                                                           |
# |0922|18583  |ATM Theft with PIN number                                                              |
# |0430|16895  |Vict shot                                                                              |
# |2032|16863  |Victim left property unattended                                                        |
# |0360|16325  |Suspect is Other Family Member                                                         |
# |0923|16306  |Stolen/Forged Checks (Personal Checks)                                                 |
# |1212|15869  |LA Police Officer                                                                      |
# |0500|15613  |Sex related acts                                                                       |
# |0311|15529  |Graffiti                                                                               |
# |0561|15259  |Suspect is Victim's Son                                                                |
# |0371|15199  |Gang affiliation questions asked/made gang statement                                   |
# |1906|15085  |Harrassing E-Mail/Text Message/Other Electronic Communications                         |
# |1221|14545  |Missing Clothing/Jewelry                                                               |
# |1236|14482  |Clerk/Employer/Owner                                                                   |
# |1605|13327  |Lock slip/key/pick                                                                     |
# |0527|13294  |Actual Intercourse                                                                     |
# |0917|13292  |Victim's Employment                                                                    |
# |0401|13049  |Bit                                                                                    |
# |0601|12641  |Business                                                                               |
# |1810|12437  |Susp is/was roommate                                                                   |
# |0345|12104  |Riding bike                                                                            |
# |0356|12100  |Suspect spits on victim                                                                |
# |1241|11889  |Spouse                                                                                 |
# |1266|11714  |Victim was security guard                                                              |
# |0314|11673  |Hot Prowl                                                                              |
# |0397|11309  |Cut lock (to bicycle                                                                   |
# |0800|11083  |BUNCO                                                                                  |
# |1608|10988  |Removed                                                                                |
# |0945|10951  |Estes Robbery                                                                          |
# |2024|10831  |Suspect was Juvenile                                                                   |
# |0378|10761  |Brings own bag                                                                         |
# |0554|10759  |Suspect is Victim's Brother                                                            |
# |1816|10437  |Suspect is/was known gang member                                                       |
# |0326|9971   |Used driver                                                                            |
# |0450|9856   |Suspect shot at victim (no hits)                                                       |
# |1821|9824   |Spouse                                                                                 |
# |1820|9809   |Friend                                                                                 |
# |0552|9593   |Suspect is Victim's Father                                                             |
# |1257|9497   |Victim is Newborn-5 years old                                                          |
# |0431|9466   |Sprayed with chemical                                                                  |
# |2021|9204   |Suspect was Aged (60+over)                                                             |
# |1313|8802   |Suspect exits vehicle and attacks pedestrian                                           |
# |1210|8668   |Professional (doctor                                                                   |
# |0312|8556   |Gun in waistband                                                                       |
# |0369|8468   |Suspect speaks spanish                                                                 |
# |0340|8387   |Suspect follows victim/follows victim home                                             |
# |0449|8327   |Put a weapon to body                                                                   |
# |0553|8046   |Suspect is Victim's Mother                                                             |
# |0924|7924   |Stolen/Forged Checks (Business Checks)                                                 |
# |1912|7882   |Threatening E-mail/Text Messages                                                       |
# |0422|7643   |Threaten Victims family                                                                |
# |1415|7407   |Rape Kit                                                                               |
# |0919|7300   |Road Rage                                                                              |
# |0370|7128   |Frisks victim/pats down victim/searches victim                                         |
# |1419|6989   |Firearm booked as evidence                                                             |
# |0354|6764   |Suspect takes car keys                                                                 |
# |0935|6709   |Misc. Stolen/Forged documents                                                          |
# |1803|6643   |Susp is/was victim's employee                                                          |
# |0209|6532   |Mask                                                                                   |
# |2003|6523   |Suspect was 5150/mentally disabled                                                     |
# |1815|6503   |Susp was student                                                                       |
# |0529|6290   |Indecent Exposure                                                                      |
# |0336|6227   |Chain snatch                                                                           |
# |0327|6198   |Used lookout                                                                           |
# |2034|6051   |Victim was asleep/unconscious                                                          |
# |1240|5953   |Vehicle occupant/Passenger                                                             |
# |0562|5653   |Suspect is Victim's Daughter                                                           |
# |0907|5589   |Narcotics (Buy-Sell-Rip)                                                               |
# |0515|5537   |Put hand                                                                               |
# |1312|5533   |Suspect follows victim in vehicle                                                      |
# |0503|5407   |Fondle victim                                                                          |
# |0537|5293   |Suspect removes victim's clothing                                                      |
# |0551|5277   |Suspect touches victim genitalia/genitals over clothing                                |
# |0510|5267   |Kissed victims body/face                                                               |
# |2033|5169   |Victim refused to cooperate w/investigation                                            |
# |0386|5165   |Suspect removed property from trunk of vehicle                                         |
# |2001|5099   |Suspect on drugs                                                                       |
# |0903|5016   |Hatred/Prejudice                                                                       |
# |2028|5006   |Suspect was Repeat/known shoplifter                                                    |
# |0330|4894   |Victims vehicle taken                                                                  |
# |0533|4771   |Consentual Sex                                                                         |
# |0359|4700   |Made unusual statement                                                                 |
# |0605|4613   |Traffic Accident/Traffic related incident                                              |
# |0916|4581   |Forced theft of vehicle (Car-Jacking)                                                  |
# |0324|4567   |Takes money from register                                                              |
# |1612|4384   |Punched/Pulled Door Lock                                                               |
# |1802|4374   |Susp is/was victim's co-worker                                                         |
# |0418|4262   |Kidnapped                                                                              |
# |0349|4241   |Takes mail                                                                             |
# |0528|3930   |Masturbate                                                                             |
# |1409|3927   |Clothes                                                                                |
# |0555|3849   |Suspect is Victim's Sister                                                             |
# |0206|3705   |Gloves                                                                                 |
# |1019|3346   |Money                                                                                  |
# |1276|3322   |Pregnant                                                                               |
# |0507|3287   |Forced to orally copulate suspect                                                      |
# |0309|3216   |Drive-by shooting                                                                      |
# |0519|3105   |Sodomy                                                                                 |
# |1275|3070   |Vacant Residence/Building                                                              |
# |1242|2950   |Parent                                                                                 |
# |0531|2942   |Suspect made sexually suggestive remarks                                               |
# |1823|2939   |Brief encounter/Date                                                                   |
# |1824|2854   |Classmate                                                                              |
# |1403|2818   |Fingerprints                                                                           |
# |1237|2752   |Victim was customer                                                                    |
# |0536|2682   |Suspect removes own clothing                                                           |
# |0512|2603   |Orally copulated victim                                                                |
# |2052|2589   |Suspect was passenger on train                                                         |
# |0420|2585   |Searched                                                                               |
# |0558|2541   |Suspect is Victim's Uncle                                                              |
# |0556|2535   |Suspect is Victim's Step-Father                                                        |
# |0390|2492   |Purse snatch                                                                           |
# |1238|2456   |Victim was physically disabled                                                         |
# |1270|2449   |Victim was gang member                                                                 |
# |1203|2440   |Victim of crime past 12 months                                                         |
# |1913|2410   |Suspect meets victim on internet/chatroom                                              |
# |0516|2407   |Reached climax/ejaculated                                                              |
# |1223|2379   |Riding bike                                                                            |
# |0316|2374   |Makes victim give money                                                                |
# |0347|2338   |Stalks vict                                                                            |
# |0380|2308   |Distracts Victim                                                                       |
# |0353|2305   |Weapon Concealed                                                                       |
# |2049|2285   |Victim was passenger on bus                                                            |
# |0315|2284   |Jumped counter/goes behind counter                                                     |
# |1311|2282   |Victim removed from vehicle                                                            |
# |2051|2272   |Suspect was passenger on bus                                                           |
# |1900|2260   |Auction Fraud/eBay/cragslist                                                           |
# |1701|2183   |Elder Abuse/Physical                                                                   |
# |1267|2166   |Home under construction                                                                |
# |0532|2155   |Suspect undressed victim                                                               |
# |1000|2123   |Suspects offers/solicits                                                               |
# |0213|1950   |Ski mask                                                                               |
# |1216|1946   |Sales                                                                                  |
# |1268|1918   |Victim was 5150/Mental Illness                                                         |
# |9999|1901   |Indistinctive MO                                                                       |
# |0389|1893   |Knock-knock                                                                            |
# |1205|1847   |On Vacation/Tourist                                                                    |
# |0908|1837   |Prostitution                                                                           |
# |1305|1829   |Victim forced into vehicle                                                             |
# |2055|1796   |Victim targeted based on Race/Ethnicity/Ancestry                                       |
# |1252|1793   |Victim was a street vendor                                                             |
# |1278|1788   |Victim was Uber/Lyft driver                                                            |
# |0375|1729   |Removes cash register                                                                  |
# |1222|1693   |Victim was gay                                                                         |
# |2048|1677   |Victim was on transit platform                                                         |
# |0925|1628   |Stolen/Forged Checks (Cashier's Checks)                                                |
# |2050|1619   |Victim was passenger on train                                                          |
# |0940|1608   |Met online/Chat Room/on Party Line                                                     |
# |0931|1578   |Counterfeit or forged real estate documents                                            |
# |0914|1556   |Other Felony                                                                           |
# |0545|1507   |Male Victim of sexual assault                                                          |
# |0509|1490   |Hugged                                                                                 |
# |0382|1466   |Removed money/property from safe                                                       |
# |1916|1460   |Victim paid by wire transfer                                                           |
# |1801|1443   |Susp is/was mother's boyfriend                                                         |
# |1804|1413   |Susp is/was victim's employer                                                          |
# |0409|1408   |Cover mouth w/hands                                                                    |
# |0381|1407   |Suspect apologizes                                                                     |
# |0404|1406   |Bomb Threat                                                                            |
# |0306|1401   |Crime on upper floor                                                                   |
# |1811|1361   |Susp is/was victim's teacher/coach                                                     |
# |0363|1357   |Home invasion                                                                          |
# |1818|1348   |Caretaker/care-giver/nanny                                                             |
# |0926|1343   |Forged or Telephonic Prescription                                                      |
# |2047|1330   |Victim was injured requiring transportation away from scene for medical reasons        |
# |0308|1322   |Demands jewelry                                                                        |
# |0387|1310   |Weapon (other than gun) in waistband                                                   |
# |1914|1295   |Unauthorized access to computer system                                                 |
# |0207|1290   |Handkerchief                                                                           |
# |1317|1254   |Victim exiting their vehicle                                                           |
# |1413|1208   |Paint                                                                                  |
# |1915|1199   |Internet Extortion                                                                     |
# |0304|1189   |Ate/drank on premises                                                                  |
# |1262|1175   |Raped while unconscious                                                                |
# |1217|1153   |Teenager(Use if victim's age is unknown)                                               |
# |2014|1141   |Suspect was Uber/Lyft driver                                                           |
# |0520|1140   |Solicited/offered immoral act                                                          |
# |1306|1128   |Victim parking                                                                         |
# |0943|1108   |Human Trafficking                                                                      |
# |1022|1107   |Ride                                                                                   |
# |1234|1105   |Bar Customer                                                                           |
# |0413|1105   |Drugged                                                                                |
# |1008|1071   |Cigarette                                                                              |
# |2007|1071   |Suspect was gay                                                                        |
# |1256|1066   |Patron                                                                                 |
# |1026|1059   |Use the phone or toilet                                                                |
# |1215|1050   |Prostitute                                                                             |
# |0526|1044   |Utilized Condom                                                                        |
# |0514|1034   |Pornography                                                                            |
# |1231|1028   |Taxi Driver                                                                            |
# |1253|996    |Bus Driver                                                                             |
# |1261|992    |Victim was mentally challenged/mentally disabled                                       |
# |1213|984    |LA Fireman                                                                             |
# |1281|962    |Victim was Pistol-whipped                                                              |
# |1610|959    |Tunneled                                                                               |
# |0406|957    |Brutal Assault                                                                         |
# |0112|925    |Police                                                                                 |
# |0351|915    |Disabled Security                                                                      |
# |1247|913    |Opening business                                                                       |
# |1805|910    |Susp is/was fellow gang member                                                         |
# |1514|910    |Bias: AntI-Black or African American                                                   |
# |0374|908    |Gang signs/threw gang signs using hands                                                |
# |0341|904    |Makes vict lie down                                                                    |
# |0339|903    |Disables video camera                                                                  |
# |1227|900    |Delivery person                                                                        |
# |2060|874    |Victim inside tent                                                                     |
# |0501|871    |Susp ejaculated outside victim                                                         |
# |2035|867    |Racial slurs                                                                           |
# |0407|861    |Burned Victim                                                                          |
# |0426|832    |Twisted arm                                                                            |
# |1020|814    |Narcotics                                                                              |
# |1271|800    |Victim was Law Enforcement (not LAPD)                                                  |
# |1401|787    |Blood Stains                                                                           |
# |2036|773    |Hate-related language                                                                  |
# |0538|770    |Suspect fondles self                                                                   |
# |2018|761    |Cannabis related                                                                       |
# |2054|736    |Victim targeted based on sexual orientation                                            |
# |1017|729    |Information                                                                            |
# |1304|727    |Stopped victim vehicle by flagging down                                                |
# |1819|715    |Common-law Spouse                                                                      |
# |0942|708    |Party/Flier party/Rave Party                                                           |
# |0921|708    |Hate Incident                                                                          |
# |2006|707    |Suspect was transgender                                                                |
# |1308|702    |Drives by and snatches property                                                        |
# |0338|701    |Disables Telephone                                                                     |
# |2053|676    |Victim targeted based on religion                                                      |
# |1273|672    |Home was being fumigated                                                               |
# |0513|645    |Photographed victim                                                                    |
# |0368|642    |Suspect speaks foreign language                                                        |
# |2041|635    |Harassment via Social Media                                                            |
# |0508|628    |Hit victim prior                                                                       |
# |0542|625    |Orders victim to undress                                                               |
# |0911|624    |Revenge                                                                                |
# |1316|617    |Victim entering their vehicle                                                          |
# |1536|617    |Bias: Anti-Gay (Male)                                                                  |
# |0540|609    |Suspect puts finger(s) in victim's rectum                                              |
# |1528|609    |Bias: Anti-Jewish                                                                      |
# |0201|608    |Bag                                                                                    |
# |2040|603    |Threats via Social Media                                                               |
# |0373|600    |Physicall disabled/in wheelchair                                                       |
# |1239|590    |Transgender                                                                            |
# |1318|587    |Suspect follows victim home                                                            |
# |0372|575    |Photographed victim/took pictures of victim                                            |
# |1611|574    |Shaved Key                                                                             |
# |1809|569    |Susp is/was rival gang member                                                          |
# |0335|558    |Cases location                                                                         |
# |2029|554    |Victim used profanity                                                                  |
# |1214|548    |Banking                                                                                |
# |1812|547    |Susp is/was foster parent/sibling                                                      |
# |1009|545    |Directions                                                                             |
# |1225|543    |Stop sign/light                                                                        |
# |0332|539    |Mailbox Vandalism                                                                      |
# |0307|534    |Defecated/urinated                                                                     |
# |0398|519    |Roof access (remove A/C                                                                |
# |1018|518    |Liquor                                                                                 |
# |1516|509    |Bias: Anti-Hispanic or Latino                                                          |
# |0927|505    |Fraudulent or forged school loan                                                       |
# |2005|496    |Suspect uses wheelchair                                                                |
# |1702|495    |Elder Abuse/Financial                                                                  |
# |0505|490    |Forced to fondle suspect                                                               |
# |0559|489    |Suspect is Victim's Aunt                                                               |
# |0410|480    |Covered victim's face                                                                  |
# |0121|475    |DWP/Gas Company/Utility worker                                                         |
# |0212|466    |Nude/partly nude                                                                       |
# |1902|460    |Credit Card Fraud/Theft of services via internet                                       |
# |0424|455    |Tore clothes off victim                                                                |
# |0550|453    |Suspect licks victim                                                                   |
# |1416|453    |Saliva                                                                                 |
# |0120|450    |Social Security/Medicare                                                               |
# |1314|449    |Victim loading vehicle                                                                 |
# |0383|447    |Suspect entered during open house/party/estate/yard sale                               |
# |0303|446    |Ambushed                                                                               |
# |1808|434    |Susp is/was other religious confidant                                                  |
# |0357|433    |Cuts or breaks purse strap                                                             |
# |0403|432    |Bomb Threat                                                                            |
# |0534|429    |Suspect in vehicle nude/partially nude                                                 |
# |0915|419    |Parolee                                                                                |
# |1265|413    |Mailbox                                                                                |
# |2037|405    |Temporary/Vacation rental (AirBnB                                                      |
# |0934|404    |Suspect uses victim's identity when receiving a citation                               |
# |0541|404    |Suspect puts object(s) in victim's rectum                                              |
# |0365|401    |Takeover robbery                                                                       |
# |0322|372    |Smashed display case                                                                   |
# |1204|371    |Moving                                                                                 |
# |1908|368    |Identity Theft via computer                                                            |
# |0506|358    |Forced to masturbate suspect                                                           |
# |2027|357    |Suspect was Pregnant                                                                   |
# |1604|353    |Lock Box                                                                               |
# |1408|349    |Bite Marks                                                                             |
# |0518|349    |Simulated intercourse                                                                  |
# |1260|349    |Deaf/Hearing Impaired                                                                  |
# |1315|342    |Victim unloading vehicle                                                               |
# |0405|340    |Bound                                                                                  |
# |0399|335    |Vehicle to Vehicle shooting                                                            |
# |0918|332    |Career Criminal                                                                        |
# |0947|329    |Motorized Rental Scooter/Bike (Bird                                                    |
# |0343|327    |Orders vict to rear room                                                               |
# |0384|317    |Suspect removed drugs from location                                                    |
# |0366|310    |Ordered vict to open safe                                                              |
# |0504|308    |Forced to disrobe                                                                      |
# |0391|303    |Used demand note                                                                       |
# |1903|303    |Cyberstalking (Stalking using internet to commit the crime)                            |
# |1013|302    |Food                                                                                   |
# |1230|302    |Postal employee                                                                        |
# |0433|296    |Makes victim kneel                                                                     |
# |0379|294    |Turns off lights/electricity                                                           |
# |1901|292    |Child Pornography/In possession of/Via computer                                        |
# |1219|287    |Nude                                                                                   |
# |1405|280    |Left Note                                                                              |
# |1028|278    |Suspect solicits time of day                                                           |
# |0110|266    |Involved in traffic/accident                                                           |
# |2009|264    |Suspect was Inmate/Incarcerated                                                        |
# |0415|264    |Handcuffed/Metal                                                                       |
# |0217|262    |Uniform                                                                                |
# |0301|262    |Escaped on (used) transit train                                                        |
# |0442|261    |Active Shooter/Armed person who has used deadly physical force on other                |
# |1301|259    |Forced victim vehicle to curb                                                          |
# |1027|258    |Change                                                                                 |
# |0933|258    |Suspect uses victim's identity when arrested                                           |
# |0101|257    |Aid victim                                                                             |
# |0113|256    |Renting                                                                                |
# |0200|256    |Suspect wore disguise                                                                  |
# |2011|254    |Vendor (street or sidewalk)                                                            |
# |1404|252    |Footprints                                                                             |
# |0549|251    |Suspect ejaculates in victims mouth                                                    |
# |0392|243    |False Emergency Reporting                                                              |
# |0114|243    |Repair Person                                                                          |
# |1603|243    |Knob Twist                                                                             |
# |1004|238    |Assistant                                                                              |
# |0396|237    |Used paper plates to disguise license number                                           |
# |0402|230    |Blindfolded                                                                            |
# |0393|229    |911 Abuse                                                                              |
# |1228|225    |Leaving Business Area                                                                  |
# |0310|225    |Got victim to withdraw savings                                                         |
# |0427|224    |Whipped                                                                                |
# |1011|223    |Employment                                                                             |
# |0543|221    |Orders victim to fondle suspect                                                        |
# |0557|212    |Suspect is Victim's Step-Mother                                                        |
# |2058|211    |Victim targeted based on Gender Non-conforming                                         |
# |1910|207    |Minor solicited for sex via internet/Known minor                                       |
# |0423|206    |Tied victim to object                                                                  |
# |0440|202    |Telephone/Electric Cord                                                                |
# |2023|202    |Suspect was Prostitute                                                                 |
# |1010|196    |Drink (not liquor)                                                                     |
# |1406|195    |Tool Marks                                                                             |
# |0218|193    |Wig                                                                                    |
# |1410|184    |Gun Shot Residue                                                                       |
# |0511|184    |Masochism/bondage                                                                      |
# |0328|182    |Used toilet                                                                            |
# |0364|181    |Suspect is babysitter                                                                  |
# |1510|181    |Bias: Anti-Transgender                                                                 |
# |0317|174    |Pillowcase/suitcase                                                                    |
# |2020|172    |Mistreatment of animal                                                                 |
# |2019|172    |Theft of animal (non-livestock)                                                        |
# |1272|171    |Victim was at/leaving medical/retail/non-retail cannabis location                      |
# |0395|170    |Murder/Suicide                                                                         |
# |1248|166    |Closing business                                                                       |
# |0362|165    |Suspect attempts to carry victim away                                                  |
# |0451|161    |Suffocation                                                                            |
# |0117|160    |Salesman                                                                               |
# |2030|160    |Victim used racial slurs                                                               |
# |1520|157    |Bias: Anti-White                                                                       |
# |1220|153    |Partially Nude                                                                         |
# |1513|153    |Bias: Anti-Asian                                                                       |
# |1911|152    |Theft of computer data                                                                 |
# |0439|151    |Tape/Electrical etc...                                                                 |
# |0320|151    |Quiet polite                                                                           |
# |0525|149    |Urinated                                                                               |
# |0220|149    |Suspect wore motorcycle helmet                                                         |
# |0323|146    |Smoked on premises                                                                     |
# |1277|145    |Gardner                                                                                |
# |1226|143    |Catering Truck Operator                                                                |
# |0204|142    |Clothes of opposite sex                                                                |
# |1233|140    |Bank                                                                                   |
# |1412|138    |Jewelry                                                                                |
# |1209|136    |Salesman                                                                               |
# |0437|134    |Flexcuffs/Plastic Tie                                                                  |
# |0938|133    |Animal Neglect                                                                         |
# |0521|133    |Tongue or mouth to anus                                                                |
# |1519|133    |Bias: Anti-Other Race/Ethnicity/Ancestry                                               |
# |1907|131    |Hate Crime materials/printouts/e-mails                                                 |
# |2031|131    |Victim used hate-related language                                                      |
# |0912|123    |Insurance                                                                              |
# |0376|122    |Makes victim kneel                                                                     |
# |0414|119    |Gagged                                                                                 |
# |2042|119    |Victim staying at short-term vacation rental                                           |
# |0560|117    |Suspect is Victim's Guardian                                                           |
# |0313|113    |Hid in building                                                                        |
# |1274|112    |Victim was Inmate/Incarcerated                                                         |
# |0105|109    |Delivery                                                                               |
# |1211|109    |Public Official                                                                        |
# |1806|108    |Susp is/was father's girlfriend                                                        |
# |1235|108    |Bisexual/sexually oriented towards both sexes                                          |
# |0388|108    |Suspect points laser at plane/helicopter                                               |
# |0438|103    |Rope/Cordage                                                                           |
# |0118|103    |Seeking someone                                                                        |
# |1807|99     |Susp is/was priest/pastor                                                              |
# |1201|99     |Absent-advertised in paper                                                             |
# |0208|98     |Halloween mask                                                                         |
# |0348|97     |Takeover other                                                                         |
# |0547|97     |Suspect force vict to bathe/clean/wipe                                                 |
# |2056|95     |Victim targeted based on gender                                                        |
# |0523|94     |Unable to get erection                                                                 |
# |1001|93     |Aid for vehicle                                                                        |
# |0412|92     |Disfigured                                                                             |
# |0902|91     |Political Activity                                                                     |
# |0215|91     |Unusual clothes                                                                        |
# |0932|90     |Suspect uses victim's identity in reporting a traffic collision                        |
# |1255|88     |Followed Transit System                                                                |
# |1539|88     |Bias: Anti-Lesbian/Gay/Bisexual or Transgender (Mixed Group)                           |
# |1417|86     |Semen                                                                                  |
# |0539|84     |Suspect puts hand in victim's rectum                                                   |
# |0535|82     |Suspect asks minor's name                                                              |
# |1002|82     |Amusement                                                                              |
# |1303|81     |Hid in rear seat                                                                       |
# |0425|81     |Tortured                                                                               |
# |2043|80     |Victim is owner of short-term vacation rental                                          |
# |0946|79     |Gang Feud                                                                              |
# |0109|77     |Inspector                                                                              |
# |0436|77     |Clothing                                                                               |
# |0318|76     |Prepared exit                                                                          |
# |1021|75     |Repair                                                                                 |
# |0530|74     |Used lubricant                                                                         |
# |0205|72     |Earring                                                                                |
# |1007|71     |Candy                                                                                  |
# |0102|68     |Blind                                                                                  |
# |2017|66     |Suspect was MTA Bus Driver                                                             |
# |2044|65     |Suspect staying at short-term vacation rental                                          |
# |1538|64     |Bias: Anti-Lesbian                                                                     |
# |0331|62     |Mailbox Bombing                                                                        |
# |2046|62     |Suspect damaged property equal to or exceeding $25                                     |
# |0203|61     |Cloth (with eyeholes)                                                                  |
# |0115|61     |Returning stolen property                                                              |
# |0122|61     |Contractor                                                                             |
# |2026|60     |Suspect was Deaf/hearing impaired                                                      |
# |1224|60     |Drive-through (not merchant)                                                           |
# |0944|60     |Bait Operation                                                                         |
# |0909|59     |Ritual/Occult                                                                          |
# |1245|59     |Victim was forced into residence                                                       |
# |1101|57     |Shots Fired (Animal) - Animal Services                                                 |
# |0350|55     |Concealed victim's body                                                                |
# |0901|54     |Organized Crime                                                                        |
# |0211|53     |Shoes                                                                                  |
# |1012|53     |Find a job                                                                             |
# |2010|53     |Suspect was Jailer/Police Officer                                                      |
# |0106|52     |Doctor                                                                                 |
# |1229|52     |Making bank drop                                                                       |
# |0119|51     |Sent by owner                                                                          |
# |1905|51     |Destruction of computer data                                                           |
# |0904|50     |Strike/Labor Troubles                                                                  |
# |0920|50     |Homeland Security                                                                      |
# |0546|49     |Susp instructs vict to make certain statements                                         |
# |0563|49     |Fetish                                                                                 |
# |0333|47     |Used hand held radios                                                                  |
# |1279|46     |Victim was Foster child                                                                |
# |0544|45     |Orders victim to fondle self                                                           |
# |0219|44     |Mustache-Fake                                                                          |
# |2059|44     |Vict rptd sexual assault at time of arst for unrelated incident                        |
# |0502|43     |Fecal Fetish                                                                           |
# |0103|43     |Physically disabled                                                                    |
# |1254|42     |Train Operator                                                                         |
# |0435|42     |Chain                                                                                  |
# |2015|42     |Suspect was Foster child                                                               |
# |1512|41     |Bias: Anti-Arab                                                                        |
# |1015|40     |Gift                                                                                   |
# |1232|39     |Bank                                                                                   |
# |1909|39     |Introduction of virus or contaminants into computer system/program                     |
# |1208|38     |Victim was undocumented alien                                                          |
# |0214|38     |Stocking                                                                               |
# |0517|38     |Sadism/Sexual gratification obtained by infliction of physical or mental pain on others|
# |1244|38     |Victim was forced into business                                                        |
# |1532|37     |Bias: Anti-Other Religion                                                              |
# |0441|36     |Wire                                                                                   |
# |2057|36     |Victim targeted based on disability                                                    |
# |1411|35     |Hair                                                                                   |
# |1207|34     |Hitchhiker                                                                             |
# |0428|34     |Dismembered                                                                            |
# |1526|34     |Bias: Anti-Islamic (Muslim)                                                            |
# |1418|32     |Skeleton/Bones                                                                         |
# |1280|29     |Victim was Foster parent                                                               |
# |2008|29     |In possession of a Ballistic vest                                                      |
# |0434|28     |Bed Sheets/Linens                                                                      |
# |0210|27     |Make up (males only)                                                                   |
# |0107|27     |God                                                                                    |
# |1904|26     |Denial of computer services                                                            |
# |1531|26     |Bias: Anti-Other Christian                                                             |
# |2025|25     |Suspect was Bisexual                                                                   |
# |0123|24     |Gardener/Tree Trimmer                                                                  |
# |2012|24     |Suspect was costumed character (e.g.                                                   |
# |1507|24     |Bias : Anti-female                                                                     |
# |0524|23     |Underwear Fetish                                                                       |
# |1014|23     |Game                                                                                   |
# |1517|22     |Bias: Anti-Multiple Races (Group)                                                      |
# |0937|21     |Cock Fighting                                                                          |
# |2039|21     |Victim was costumed character (e.g.                                                    |
# |1509|20     |Bias: Anti-Gender non-conforming                                                       |
# |0108|18     |Infirm                                                                                 |
# |1016|16     |Hold for safekeeping                                                                   |
# |0939|16     |Animal Hoarding                                                                        |
# |1506|16     |Bias: Physical disability                                                              |
# |0905|15     |Terrorist Group                                                                        |
# |0936|15     |Dog Fighting                                                                           |
# |0604|14     |Reproductive Health Services/Facilities                                                |
# |1269|14     |Victim was armored car driver                                                          |
# |1025|13     |Train                                                                                  |
# |1523|13     |Bias: Anti-Catholic                                                                    |
# |1515|13     |Bias: Anti-Citizenship Status                                                          |
# |1505|13     |Bias: Mental Disability                                                                |
# |1264|12     |Pipeline                                                                               |
# |1535|12     |Bias: Anti-Bisexual                                                                    |
# |2013|12     |Tour Bus/Van Operator                                                                  |
# |1527|10     |Bias: Anti-Jehovah's Witness                                                           |
# |1005|8      |Audition                                                                               |
# |2022|8      |Suspect was Hitchhiker                                                                 |
# |2045|8      |Suspect is owner of short-term vacation rental                                         |
# |1508|7      |Bias: Anti-male                                                                        |
# |0116|7      |Satan                                                                                  |
# |1525|7      |Bias: Anti-Hindu                                                                       |
# |1006|6      |Bless                                                                                  |
# |1024|6      |Teach                                                                                  |
# |1530|6      |Bias: Anti-Multiple Religions Group                                                    |
# |0367|6      |Was Transit Patrol                                                                     |
# |1522|6      |Bias: Anti-Buddhist                                                                    |
# |1511|5      |Bias: Anti-American/Alaskan Native                                                     |
# |1003|4      |appraise                                                                               |
# |1023|4      |Subscriptions                                                                          |
# |2016|4      |Suspect was Train Operator                                                             |
# |0941|4      |Non-Revocable Parole (NRP)                                                             |
# |1518|3      |Bias: Anti-Native Hawaiian or Other Pacific Islander                                   |
# |1537|3      |Bias: Anti-Heterosexual                                                                |
# |1533|3      |Bias: Anti-Protestant                                                                  |
# |1263|2      |Agricultural Target                                                                    |
# |0548|1      |Suspect gives victim douche/enema                                                      |
# |1524|1      |Bias: Anti-Eastern Orthodox (Russian/Greek/Other)                                      |
# |1534|1      |Bias: Anti-Sikh                                                                        |
# |1521|1      |Bias: Anti-Atheism/Agnosticism                                                         |
# +----+-------+---------------------------------------------------------------------------------------+
